# %% [markdown]
# Para empezar a utilizar mongodb desde 0, vamos a partir realizando los siguientes pasos:
#
#
# 1.   Instalaremos $\texttt{mongodb}$
# 2.   Inicializaremos el proceso $\texttt{mongodb}$
# 3.   Instalaremos el comando $\texttt{gdown}$ para bajar la base de datos en formato json de google drive.
# 4.   Importaremos los datos por linea de comando. Dejaremos los datos en la base de datos $\texttt{local}$, en la colección $\texttt{pokedex}$, y le informaremos al comando que los datos vienen como una arreglo de jsons.

# %%
# !apt update
# !apt install wget curl gnupg2 software-properties-common apt-transport-https ca-certificates lsb-release
# !curl -fsSL https://www.mongodb.org/static/pgp/server-6.0.asc|sudo gpg --dearmor -o /etc/apt/trusted.gpg.d/mongodb-6.gpg
# !echo "deb [ arch=amd64,arm64 ] https://repo.mongodb.org/apt/ubuntu $(lsb_release -cs)/mongodb-org/6.0 multiverse" | tee /etc/apt/sources.list.d/mongodb-org-6.0.list
# !apt update
# !apt install mongodb-org
# !mkdir /data
# !mkdir /data/db
# !mongod --fork --logpath /var/log/mongodb/mongod.log
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,194 kB]
# Get:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,331 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,458 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,226 kB]
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,626 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,543 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,515 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [3,475 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,751 kB]
# Get:20 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [49.7 kB]
# Fetched 27.6 MB in 5s (5,583 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 59 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# lsb-release is already the newest version (11.1.0ubuntu4).
# lsb-release set to manually installed.
# ca-certificates is already the newest version (20240203~22.04.1).
# curl is already the newest version (7.81.0-1ubuntu1.19).
# software-properties-common is already the newest version (0.99.22.9).
# wget is already the newest version (1.21.2-2ubuntu1.1).
# gnupg2 is already the newest version (2.2.27-3ubuntu2.1).
# The following NEW packages will be installed:
#   apt-transport-https
# 0 upgraded, 1 newly installed, 0 to remove and 59 not upgraded.
# Need to get 1,510 B of archives.
# After this operation, 170 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 apt-transport-https all 2.4.13 [1,510 B]
# Fetched 1,510 B in 0s (18.7 kB/s)
# Selecting previously unselected package apt-transport-https.
# (Reading database ... 123632 files and directories currently installed.)
# Preparing to unpack .../apt-transport-https_2.4.13_all.deb ...
# Unpacking apt-transport-https (2.4.13) ...
# Setting up apt-transport-https (2.4.13) ...
# deb [ arch=amd64,arm64 ] https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/6.0 multiverse
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:7 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/6.0 InRelease [4,009 B]
# Hit:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/6.0/multiverse amd64 Packages [77.7 kB]
# Get:13 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/6.0/multiverse arm64 Packages [74.3 kB]
# Fetched 156 kB in 2s (95.6 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 59 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   mongodb-database-tools mongodb-mongosh mongodb-org-database mongodb-org-database-tools-extra
#   mongodb-org-mongos mongodb-org-server mongodb-org-shell mongodb-org-tools
# The following NEW packages will be installed:
#   mongodb-database-tools mongodb-mongosh mongodb-org mongodb-org-database
#   mongodb-org-database-tools-extra mongodb-org-mongos mongodb-org-server mongodb-org-shell
#   mongodb-org-tools
# 0 upgraded, 9 newly installed, 0 to remove and 59 not upgraded.
# Need to get 155 MB of archives.
# After this operation, 513 MB of additional disk space will be used.
# Get:1 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/6.0/multiverse amd64 mongodb-database-tools amd64 100.10.0 [46.4 MB]
# Get:2 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/6.0/multiverse amd64 mongodb-mongosh amd64 2.3.4 [54.1 MB]
# Get:3 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/6.0/multiverse amd64 mongodb-org-shell amd64 6.0.19 [2,986 B]
# Get:4 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/6.0/multiverse amd64 mongodb-org-server amd64 6.0.19 [31.7 MB]
# Get:5 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/6.0/multiverse amd64 mongodb-org-mongos amd64 6.0.19 [22.6 MB]
# Get:6 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/6.0/multiverse amd64 mongodb-org-database-tools-extra amd64 6.0.19 [7,778 B]
# Get:7 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/6.0/multiverse amd64 mongodb-org-database amd64 6.0.19 [3,424 B]
# Get:8 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/6.0/multiverse amd64 mongodb-org-tools amd64 6.0.19 [2,772 B]
# Get:9 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/6.0/multiverse amd64 mongodb-org amd64 6.0.19 [2,802 B]
# Fetched 155 MB in 2s (72.1 MB/s)
# Selecting previously unselected package mongodb-database-tools.
# (Reading database ... 123636 files and directories currently installed.)
# Preparing to unpack .../0-mongodb-database-tools_100.10.0_amd64.deb ...
# Unpacking mongodb-database-tools (100.10.0) ...
# Selecting previously unselected package mongodb-mongosh.
# Preparing to unpack .../1-mongodb-mongosh_2.3.4_amd64.deb ...
# Unpacking mongodb-mongosh (2.3.4) ...
# Selecting previously unselected package mongodb-org-shell.
# Preparing to unpack .../2-mongodb-org-shell_6.0.19_amd64.deb ...
# Unpacking mongodb-org-shell (6.0.19) ...
# Selecting previously unselected package mongodb-org-server.
# Preparing to unpack .../3-mongodb-org-server_6.0.19_amd64.deb ...
# Unpacking mongodb-org-server (6.0.19) ...
# Selecting previously unselected package mongodb-org-mongos.
# Preparing to unpack .../4-mongodb-org-mongos_6.0.19_amd64.deb ...
# Unpacking mongodb-org-mongos (6.0.19) ...
# Selecting previously unselected package mongodb-org-database-tools-extra.
# Preparing to unpack .../5-mongodb-org-database-tools-extra_6.0.19_amd64.deb ...
# Unpacking mongodb-org-database-tools-extra (6.0.19) ...
# Selecting previously unselected package mongodb-org-database.
# Preparing to unpack .../6-mongodb-org-database_6.0.19_amd64.deb ...
# Unpacking mongodb-org-database (6.0.19) ...
# Selecting previously unselected package mongodb-org-tools.
# Preparing to unpack .../7-mongodb-org-tools_6.0.19_amd64.deb ...
# Unpacking mongodb-org-tools (6.0.19) ...
# Selecting previously unselected package mongodb-org.
# Preparing to unpack .../8-mongodb-org_6.0.19_amd64.deb ...
# Unpacking mongodb-org (6.0.19) ...
# Setting up mongodb-mongosh (2.3.4) ...
# Setting up mongodb-org-server (6.0.19) ...
# Adding system user `mongodb' (UID 104) ...
# Adding new user `mongodb' (UID 104) with group `nogroup' ...
# Not creating home directory `/home/mongodb'.
# Adding group `mongodb' (GID 107) ...
# Done.
# Adding user `mongodb' to group `mongodb' ...
# Adding user mongodb to group mongodb
# Done.
# System has not been booted with systemd as init system (PID 1). Can't operate.
# Failed to connect to bus: Host is down
# Setting up mongodb-org-shell (6.0.19) ...
# Setting up mongodb-database-tools (100.10.0) ...
# Setting up mongodb-org-mongos (6.0.19) ...
# Setting up mongodb-org-database-tools-extra (6.0.19) ...
# Setting up mongodb-org-database (6.0.19) ...
# Setting up mongodb-org-tools (6.0.19) ...
# Setting up mongodb-org (6.0.19) ...
# Processing triggers for man-db (2.10.2-1) ...
# about to fork child process, waiting until server is ready for connections.
# forked process: 2256
# child process started successfully, parent exiting

# %%
# !gdown https://drive.google.com/uc?id=108aLE4mFE5bZYitFfX5c14Qj_aYA5MO_
# !mongoimport --db local --collection pokedex --jsonArray < pokedex.json
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=108aLE4mFE5bZYitFfX5c14Qj_aYA5MO_
# To: /content/pokedex.json
# 100% 2.95M/2.95M [00:00<00:00, 143MB/s]
# 2024-12-11T16:05:30.574+0000	connected to: mongodb://localhost/
# 2024-12-11T16:05:30.956+0000	809 document(s) imported successfully. 0 document(s) failed to import.

# %% [markdown]
# A continuación importaremos la librería de mongo para python, crearemos un cliente que se conectara a $\texttt{localhost}$ por defecto, nos conectaremos a la base local, y luego a la colección pokedex la cual almacenaremos en la variable $\texttt{collection}$.

# %%
# !apt install mongodb-org
# !pip install pymongo
from pymongo import MongoClient
client = MongoClient()
client.list_database_names() # ['admin', 'local']
db = client['local']
collection = db['pokedex']
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# mongodb-org is already the newest version (6.0.19).
# 0 upgraded, 0 newly installed, 0 to remove and 59 not upgraded.
# Collecting pymongo
#   Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 21.9 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 23.1 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.10.1

# %% [markdown]
# Para partir, podemos listar toda la colección usando el comando $\texttt{collection.find({})}$. Para no saturar la salida, nos limitaremos a mirar el primero de los registros.

# %%
import pprint
for pokemon in collection.find({}).limit(1):
    pprint.pprint(pokemon)
# Out:
# {'Abilities': ['Overgrow', 'Chlorophyll'],
#  'Attack': 62,
#  'Capture Rate': 45,
#  'Category': 'Seed Pokémon',
#  'Defense': 63,
#  'Egg Steps': 5120,
#  'Exp Group': 'Medium Slow',
#  'HP': 60,
#  'Height (ft)': '3\'03"',
#  'Height (m)': 1,
#  'Id': '002',
#  'Moves': {'Double-Edge': {'Accuracy': 100,
#                            'Description': 'A reckless, life-risking tackle. '
#                                           'This also damages the user quite a '
#                                           'lot.',
#                            'Effect %': '--',
#                            'Level': 31,
#                            'PP': 15,
#                            'Power': 120,
#                            'Type': 'Normal'},
#            'Growl': {'Accuracy': 100,
#                      'Description': 'The user growls in an endearing way, '
#                                     'making opposing Pokémon less wary. This '
#                                     'lowers their Attack stat.',
#                      'Effect %': '--',
#                      'Level': 3,
#                      'PP': 40,
#                      'Power': '--',
#                      'Type': 'Normal'},
#            'Growth': {'Accuracy': '--',
#                       'Description': "The user's body grows all at once, "
#                                      'raising the Attack and Sp. Atk stats.',
#                       'Effect %': '--',
#                       'Level': 28,
#                       'PP': 20,
#                       'Power': '--',
#                       'Type': 'Normal'},
#            'Leech Seed': {'Accuracy': 90,
#                           'Description': 'A seed is planted on the target. It '
#                                          'steals some HP from the target every '
#                                          'turn.',
#                           'Effect %': '--',
#                           'Level': 7,
#                           'PP': 10,
#                           'Power': '--',
#                           'Type': 'Grass'},
#            'Poison Powder': {'Accuracy': 75,
#                              'Description': 'The user scatters a cloud of '
#                                             'poisonous dust that poisons the '
#                                             'target.',
#                              'Effect %': '--',
#                              'Level': 13,
#                              'PP': 35,
#                              'Power': '--',
#                              'Type': 'Poison'},
#            'Razor Leaf': {'Accuracy': 95,
#                           'Description': 'Sharp-edged leaves are launched to '
#                                          'slash at the opposing Pokémon. '
#                                          'Critical hits land more easily.',
#                           'Effect %': '--',
#                           'Level': 20,
#                           'PP': 25,
#                           'Power': 55,
#                           'Type': 'Grass'},
#            'Sleep Powder': {'Accuracy': 75,
#                             'Description': 'The user scatters a big cloud of '
#                                            'sleep-inducing dust around the '
#                                            'target.',
#                             'Effect %': '--',
#                             'Level': 13,
#                             'PP': 15,
#                             'Power': '--',
#                             'Type': 'Grass'},
#            'Solar Beam': {'Accuracy': 100,
#                           'Description': 'In this two-turn attack, the user '
#                                          'gathers light, then blasts a bundled '
#                                          'beam on the next turn.',
#                           'Effect %': '--',
#                           'Level': 44,
#                           'PP': 10,
#                           'Power': 120,
#                           'Type': 'Grass'},
#            'Sweet Scent': {'Accuracy': 100,
#                            'Description': 'A sweet scent that harshly lowers '
#                                           "opposing Pokémon's evasiveness.",
#                            'Effect %': '--',
#                            'Level': 23,
#                            'PP': 20,
#                            'Power': '--',
#                            'Type': 'Normal'},
#            'Synthesis': {'Accuracy': '--',
#                          'Description': 'The user restores its own HP. The '
#                                         'amount of HP regained varies with the '
#                                         'weather.',
#                          'Effect %': '--',
#                          'Level': 39,
#                          'PP': 5,
#                          'Power': '--',
#                          'Type': 'Grass'},
#            'Tackle': {'Accuracy': 100,
#                       'Description': 'A physical attack in which the user '
#                                      'charges and slams into the target with '
#                                      'its whole body.',
#                       'Effect %': '--',
#                       'Level': '—',
#                       'PP': 35,
#                       'Power': 40,
#                       'Type': 'Normal'},
#            'Take Down': {'Accuracy': 85,
#                          'Description': 'A reckless, full-body charge attack '
#                                         'for slamming into the target. This '
#                                         'also damages the user a little.',
#                          'Effect %': '--',
#                          'Level': 15,
#                          'PP': 20,
#                          'Power': 90,
#                          'Type': 'Normal'},
#            'Vine Whip': {'Accuracy': 100,
#                          'Description': 'The target is struck with slender, '
#                                         'whiplike vines to inflict damage.',
#                          'Effect %': '--',
#                          'Level': 9,
#                          'PP': 25,
#                          'Power': 45,
#                          'Type': 'Grass'},
#            'Worry Seed': {'Accuracy': 100,
#                           'Description': 'A seed that causes worry is planted '
#                                          'on the target. It prevents sleep by '
#                                          "making the target's Ability "
#                                          'Insomnia.',
#                           'Effect %': '--',
#                           'Level': 36,
#                           'PP': 10,
#                           'Power': '--',
#                           'Type': 'Grass'}},
#  'Name': 'Ivysaur',
#  'Sp. Attack': 80,
#  'Sp. Defense': 80,
#  'Speed': 60,
#  'Total': 405,
#  'Type 1': 'Grass',
#  'Type 2': 'Poison',
#  'Weight (kg)': 13,
#  'Weight (lbs)': 28.7,
#  '_id': ObjectId('673d4be633db6a5f28b6708b')}

# %% [markdown]
# Fijense que aparte de los datos básicos del pokemon, también se presentan las habilidades (una lista de strings), y los movimientos (un arreglo asociativo/diccionario de los movimientos y sus detalles).
#
# Si queremos ahora listar los pokemones que se llaman $\texttt{Charmander}$ podemos hacer la siguiente consulta:

# %%
for pokemon in collection.find({'Name': 'Charmander'}):
    pprint.pprint(pokemon)
# Out:
# {'Abilities': ['Blaze', 'Solar Power'],
#  'Attack': 52,
#  'Capture Rate': 45,
#  'Category': 'Lizard Pokémon',
#  'Defense': 43,
#  'Egg Steps': 5120,
#  'Exp Group': 'Medium Slow',
#  'HP': 39,
#  'Height (ft)': '2\'00"',
#  'Height (m)': 0.6,
#  'Id': '004',
#  'Moves': {'Dragon Rage': {'Accuracy': 100,
#                            'Description': 'This attack hits the target with a '
#                                           'shock wave of pure rage. This '
#                                           'attack always inflicts 40 HP '
#                                           'damage.',
#                            'Effect %': '--',
#                            'Level': 16,
#                            'PP': 10,
#                            'Power': '??',
#                            'Type': 'Dragon'},
#            'Ember': {'Accuracy': 100,
#                      'Description': 'The target is attacked with small flames. '
#                                     'This may also leave the target with a '
#                                     'burn.',
#                      'Effect %': 10,
#                      'Level': 7,
#                      'PP': 25,
#                      'Power': 40,
#                      'Type': 'Fire'},
#            'Fire Fang': {'Accuracy': 95,
#                          'Description': 'The user bites with flame-cloaked '
#                                         'fangs. This may also make the target '
#                                         'flinch or leave it with a burn.',
#                          'Effect %': 20,
#                          'Level': 19,
#                          'PP': 15,
#                          'Power': 65,
#                          'Type': 'Fire'},
#            'Fire Spin': {'Accuracy': 85,
#                          'Description': 'The target becomes trapped within a '
#                                         'fierce vortex of fire that rages for '
#                                         'four to five turns.',
#                          'Effect %': 100,
#                          'Level': 37,
#                          'PP': 15,
#                          'Power': 35,
#                          'Type': 'Fire'},
#            'Flame Burst': {'Accuracy': 100,
#                            'Description': 'The user attacks the target with a '
#                                           'bursting flame. The bursting flame '
#                                           'damages Pokémon next to the target '
#                                           'as well.',
#                            'Effect %': '--',
#                            'Level': 25,
#                            'PP': 15,
#                            'Power': 70,
#                            'Type': 'Fire'},
#            'Flamethrower': {'Accuracy': 100,
#                             'Description': 'The target is scorched with an '
#                                            'intense blast of fire. This may '
#                                            'also leave the target with a burn.',
#                             'Effect %': 10,
#                             'Level': 34,
#                             'PP': 15,
#                             'Power': 90,
#                             'Type': 'Fire'},
#            'Growl': {'Accuracy': 100,
#                      'Description': 'The user growls in an endearing way, '
#                                     'making opposing Pokémon less wary. This '
#                                     'lowers their Attack stat.',
#                      'Effect %': '--',
#                      'Level': '—',
#                      'PP': 40,
#                      'Power': '--',
#                      'Type': 'Normal'},
#            'Inferno': {'Accuracy': 50,
#                        'Description': 'The user attacks by engulfing the '
#                                       'target in an intense fire. This leaves '
#                                       'the target with a burn.',
#                        'Effect %': 100,
#                        'Level': 43,
#                        'PP': 5,
#                        'Power': 100,
#                        'Type': 'Fire'},
#            'Scary Face': {'Accuracy': 100,
#                           'Description': 'The user frightens the target with a '
#                                          'scary face to harshly lower its '
#                                          'Speed stat.',
#                           'Effect %': '--',
#                           'Level': 40,
#                           'PP': 10,
#                           'Power': '--',
#                           'Type': 'Normal'},
#            'Scratch': {'Accuracy': 100,
#                        'Description': 'Hard, pointed, sharp claws rake the '
#                                       'target to inflict damage.',
#                        'Effect %': '--',
#                        'Level': '—',
#                        'PP': 35,
#                        'Power': 40,
#                        'Type': 'Normal'},
#            'Slash': {'Accuracy': 100,
#                      'Description': 'The target is attacked with a slash of '
#                                     'claws or blades. Critical hits land more '
#                                     'easily.',
#                      'Effect %': '--',
#                      'Level': 28,
#                      'PP': 20,
#                      'Power': 70,
#                      'Type': 'Normal'},
#            'Smokescreen': {'Accuracy': 100,
#                            'Description': 'The user releases an obscuring '
#                                           'cloud of smoke or ink. This lowers '
#                                           "the target's accuracy.",
#                            'Effect %': '--',
#                            'Level': 10,
#                            'PP': 20,
#                            'Power': '--',
#                            'Type': 'Normal'}},
#  'Name': 'Charmander',
#  'Sp. Attack': 60,
#  'Sp. Defense': 50,
#  'Speed': 65,
#  'Total': 309,
#  'Type 1': 'Fire',
#  'Type 2': 'None',
#  'Weight (kg)': 8.5,
#  'Weight (lbs)': 18.7,
#  '_id': ObjectId('673d4be633db6a5f28b6708e')}

# %% [markdown]
# Y si queremos proyectar algunos de sus atributos lo hacemos tal como si fuera un diccionario:

# %%
for pokemon in collection.find({'Name': 'Mew'}):
    print(pokemon['Speed'],pokemon['Abilities'])
# Out:
# 100 ['Synchronize']

# %% [markdown]
# Recomendamos hechar un vistazo [aquí](https://docs.mongodb.com/manual/tutorial/query-documents/) para ver otros ejemplos de consultas que utilizarán en las siguientes preguntas:

# %% [markdown]
# #Pregunta 1
# Encuentre los nombre de los pokemons que pesen mas de 150kg.
# [Ordene](https://www.w3schools.com/python/python_mongodb_sort.asp) los resultados por peso descendiente

# %%
for pokemon in collection.find({'Weight (kg)': {'$gt': 150}}):
    print(pokemon['Name'])
# Out:
# Arcanine
# Golem
# Onix
# Gyarados
# Lapras
# Snorlax
# Dragonite
# Steelix
# Mantine
# Kingdra
# Entei
# Raikou
# Suicune
# Pupitar
# Tyranitar
# Lugia
# Ho-Oh
# Hariyama
# Aggron
# Wailord
# Camerupt
# Solrock
# Lunatone
# Milotic
# Glalie
# Walrein
# Metang
# Metagross
# Regirock
# Regice
# Registeel
# Kyogre
# Rayquaza
# Groudon
# Torterra
# Bronzong
# Hippowdon
# Magnezone
# Rhyperior
# Mamoswine
# Probopass
# Dialga
# Palkia
# Heatran
# Regigigas
# Giratina
# Arceus
# Gigalith
# Scolipede
# Crustle
# Beartic
# Golurk
# Hydreigon
# Cobalion
# Terrakion
# Virizion
# Reshiram
# Zekrom
# Kyurem
# Tyrantrum
# Aurorus
# Goodra
# Avalugg
# Xerneas
# Yveltal
# Zygarde
# Volcanion
# Crabominable
# Mudsdale
# Palossand
# Turtonator
# Drampa
# Dhelmise
# Cosmoem
# Solgaleo
# Buzzwole
# Guzzlord
# Necrozma
# Celesteela
# Stakataka
# Melmetal

# %% [markdown]
# #Pregunta 2
# Encuentre los nombres de los pokemones ''Glass cannon'', que son los que tienen ataque sobre 120 y defensa bajo 50.

# %%
for pokemon in collection.find({'$and': [{'Attack': {'$gt': 120}}, {'Defense': {'$lt': 50}}]}):
    print(pokemon['Name'])
# Out:
# Cranidos
# Pheromosa

# %% [markdown]
# #Pregunta 3
# Encuentre los pokemones "defensivos", que son los que tienen ya sea defensa, hp, o defensa especial (sp. defense) mayor o igual a 120.

# %%
for pokemon in collection.find({'$or': [{'Defense': {'$gte': 120}}, {'HP': {'$gte': 120}}, {'Sp. Defense': {'$gte': 120}}]}):
    pprint.pprint(pokemon)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#                           'Effect %': 20,
#                           'Level': '—',
#                           'PP': 20,
#                           'Power': 90,
#                           'Type': 'Normal'},
#            'Rollout': {'Accuracy': 90,
#                        'Description': 'The user continually rolls into the '
#                                       'target over five turns. It becomes more '
#                                       'powerful each time it hits.',
#                        'Effect %': '--',
#                        'Level': 6,
#                        'PP': 20,
#                        'Power': 30,
#                        'Type': 'Rock'},
#            'Self-Destruct': {'Accuracy': 100,
#                              'Description': 'The user attacks everything '
#                                             'around it by causing an '
#                                             'explosion. The user faints upon '
#                                             'using this move.',
#                              'Effect %': '--',
#                              'Level': 38,
#                              'PP': 5,
#                              'Power': 200,
#                              'Type': 'Normal'},
#            'Tackle': {'Accuracy': 100,
#                       'Description': 'A physical attack in which the user '
#                                      'charges and slams into the target with '
#                                      'its whole body.',
#                       'Effect %': '--',
#                       'Level': '—',
#                       'PP': 35,
#                       'Power': 40,
#                       'Type': 'Normal'}},
#  'Name': 'Ferrothorn',
#  'Sp. Attack': 54,
#  'Sp. Defense': 116,
#  'Speed': 20,
#  'Total': 489,
#  'Type 1': 'Grass',
#  'Type 2': 'Steel',
#  'Weight (kg)': 110,
#  'Weight (lbs)': 242.5,
#  '_id': ObjectId('6759b84a0aaca17d8a11f77e')}
# {'Abilities': ['Justified'],
#  'Attack': 90,
#  'Capture Rate': 3,
#  'Category': 'Iron Will Pokémon',
#  'Defense': 129,
#  'Egg Steps': 20480,
#  'Exp Group': 'Slow',
#  'HP': 91,
#  'Height (ft)': '6\'11"',
#  'Height (m)': 2.1,
#  'Id': '638',
#  'Moves': {'Close Combat': {'Accuracy': 100,
#                             'Description': 'The user fights the target up '
#                                            'close without guarding itself. '
#                                            "This also lowers the user's "
#                                            'Defense and Sp. Def stats.',
#                             'Effect %': 100,
#                             'Level': 61,
#                             'PP': 5,
#                             'Power': 120,
#                             'Type': 'Fighting'},
#            'Double Kick': {'Accuracy': 100,
#                            'Description': 'The target is quickly kicked twice '
#                                           'in succession using both feet.',
#                            'Effect %': '--',
#                            'Level': '—',
#                            'PP': 30,
#                            'Power': 30,
#                            'Type': 'Fighting'},
#            'Helping Hand': {'Accuracy': '--',
#                             'Description': 'The user assists an ally by '
#                                            "boosting the power of that ally's "
#                                            'attack.',
#                             'Effect %': '--',
#                             'Level': 13,
#                             'PP': 20,
#                             'Power': '--',
#                             'Type': 'Normal'},
#            'Iron Head': {'Accuracy': 100,
#                          'Description': 'The user slams the target with its '
#                                         'steel-hard head. This may also make '
#                                         'the target flinch.',
#                          'Effect %': 30,
#                          'Level': 25,
#                          'PP': 15,
#                          'Power': 80,
#                          'Type': 'Steel'},
#            'Leer': {'Accuracy': 100,
#                     'Description': 'The user gives opposing Pokémon an '
#                                    'intimidating leer that lowers the Defense '
#                                    'stat.',
#                     'Effect %': 100,
#                     'Level': '—',
#                     'PP': 30,
#                     'Power': '--',
#                     'Type': 'Normal'},
#            'Metal Burst': {'Accuracy': 100,
#                            'Description': 'The user retaliates with much '
#                                           'greater force against the opponent '
#                                           'that last inflicted damage on it.',
#                            'Effect %': '--',
#                            'Level': 55,
#                            'PP': 10,
#                            'Power': '??',
#                            'Type': 'Steel'},
#            'Metal Claw': {'Accuracy': 95,
#                           'Description': 'The target is raked with steel '
#                                          'claws. This may also raise the '
#                                          "user's Attack stat.",
#                           'Effect %': 10,
#                           'Level': '—',
#                           'PP': 35,
#                           'Power': 50,
#                           'Type': 'Steel'},
#            'Quick Attack': {'Accuracy': 100,
#                             'Description': 'The user lunges at the target at a '
#                                            'speed that makes it almost '
#                                            'invisible. This move always goes '
#                                            'first.',
#                             'Effect %': '--',
#                             'Level': '—',
#                             'PP': 30,
#                             'Power': 40,
#                             'Type': 'Normal'},
#            'Quick Guard': {'Accuracy': '--',
#                            'Description': 'The user protects itself and its '
#                                           'allies from priority moves.',
#                            'Effect %': '--',
#                            'Level': 42,
#                            'PP': 15,
#                            'Power': '--',
#                            'Type': 'Fighting'},
#            'Retaliate': {'Accuracy': 100,
#                          'Description': 'The user gets revenge for a fainted '
#                                         'ally. If an ally fainted in the '
#                                         "previous turn, this move's power is "
#                                         'increased.',
#                          'Effect %': '--',
#                          'Level': 19,
#                          'PP': 5,
#                          'Power': 70,
#                          'Type': 'Normal'},
#            'Sacred Sword': {'Accuracy': 100,
#                             'Description': 'The user attacks by slicing with a '
#                                            "long horn. The target's stat "
#                                            "changes don't affect this attack's "
#                                            'damage.',
#                             'Effect %': '--',
#                             'Level': 31,
#                             'PP': 15,
#                             'Power': 90,
#                             'Type': 'Fighting'},
#            'Swords Dance': {'Accuracy': '--',
#                             'Description': 'A frenetic dance to uplift the '
#                                            'fighting spirit. This sharply '
#                                            "raises the user's Attack stat.",
#                             'Effect %': '--',
#                             'Level': 37,
#                             'PP': 20,
#                             'Power': '--',
#                             'Type': 'Normal'},
#            'Take Down': {'Accuracy': 85,
#                          'Description': 'A reckless, full-body charge attack '
#                                         'for slamming into the target. This '
#                                         'also damages the user a little.',
#                          'Effect %': '--',
#                          'Level': 7,
#                          'PP': 20,
#                          'Power': 90,
#                          'Type': 'Normal'},
#            'Work Up': {'Accuracy': '--',
#                        'Description': 'The user is roused, and its Attack and '
#                                       'Sp. Atk stats increase.',
#                        'Effect %': '--',
#                        'Level': 49,
#                        'PP': 30,
#                        'Power': '--',
#                        'Type': 'Normal'}},
#  'Name': 'Cobalion',
#  'Sp. Attack': 90,
#  'Sp. Defense': 72,
#  'Speed': 108,
#  'Total': 580,
#  'Type 1': 'Steel',
#  'Type 2': 'Fighting',
#  'Weight (kg)': 250,
#  'Weight (lbs)': 551.1,
#  '_id': ObjectId('6759b84a0aaca17d8a11f7a4')}
# {'Abilities': ['Teravolt'],
#  'Attack': 150,
#  'Capture Rate': 3,
#  'Category': 'Deep Black Pokémon',
#  'Defense': 120,
#  'Egg Steps': 30720,
#  'Exp Group': 'Slow',
#  'HP': 100,
#  'Height (ft)': '9\'06"',
#  'Height (m)': 2.9,
#  'Id': '644',
#  'Moves': {'Ancient Power': {'Accuracy': 100,
#                              'Description': 'The user attacks with a '
#                                             'prehistoric power. This may also '
#                                             "raise all the user's stats at "
#                                             'once.',
#                              'Effect %': 10,
#                              'Level': 8,
#                              'PP': 5,
#                              'Power': 60,
#                              'Type': 'Rock'},
#            'Bolt Strike': {'Accuracy': 85,
#                            'Description': 'The user surrounds itself with a '
#                                           'great amount of electricity and '
#                                           'charges its target. This may also '
#                                           'leave the target with paralysis.',
#                            'Effect %': 20,
#                            'Level': 92,
#                            'PP': 5,
#                            'Power': 130,
#                            'Type': 'Electric'},
#            'Crunch': {'Accuracy': 100,
#                       'Description': 'The user crunches up the target with '
#                                      'sharp fangs. This may also lower the '
#                                      "target's Defense stat.",
#                       'Effect %': 20,
#                       'Level': 64,
#                       'PP': 15,
#                       'Power': 80,
#                       'Type': 'Dark'},
#            'Dragon Breath': {'Accuracy': 100,
#                              'Description': 'The user exhales a mighty gust '
#                                             'that inflicts damage. This may '
#                                             'also leave the target with '
#                                             'paralysis.',
#                              'Effect %': 30,
#                              'Level': 22,
#                              'PP': 20,
#                              'Power': 60,
#                              'Type': 'Dragon'},
#            'Dragon Claw': {'Accuracy': 100,
#                            'Description': 'The user slashes the target with '
#                                           'huge sharp claws.',
#                            'Effect %': '--',
#                            'Level': 50,
#                            'PP': 15,
#                            'Power': 80,
#                            'Type': 'Dragon'},
#            'Dragon Rage': {'Accuracy': 100,
#                            'Description': 'This attack hits the target with a '
#                                           'shock wave of pure rage. This '
#                                           'attack always inflicts 40 HP '
#                                           'damage.',
#                            'Effect %': '--',
#                            'Level': '—',
#                            'PP': 10,
#                            'Power': '??',
#                            'Type': 'Dragon'},
#            'Fusion Bolt': {'Accuracy': 100,
#                            'Description': 'The user throws down a giant '
#                                           "lightning bolt. This move's power "
#                                           'is increased when influenced by an '
#                                           'enormous flame.',
#                            'Effect %': '--',
#                            'Level': 43,
#                            'PP': 5,
#                            'Power': 100,
#                            'Type': 'Electric'},
#            'Hyper Voice': {'Accuracy': 100,
#                            'Description': 'The user lets loose a horribly '
#                                           'echoing shout with the power to '
#                                           'inflict damage.',
#                            'Effect %': '--',
#                            'Level': 85,
#                            'PP': 10,
#                            'Power': 90,
#                            'Type': 'Normal'},
#            'Imprison': {'Accuracy': '--',
#                         'Description': 'If opposing Pokémon know any move also '
#                                        'known by the user, they are prevented '
#                                        'from using it.',
#                         'Effect %': '--',
#                         'Level': 54,
#                         'PP': 10,
#                         'Power': '--',
#                         'Type': 'Psychic'},
#            'Outrage': {'Accuracy': 100,
#                        'Description': 'The user rampages and attacks for two '
#                                       'to three turns. The user then becomes '
#                                       'confused.',
#                        'Effect %': '--',
#                        'Level': 78,
#                        'PP': 10,
#                        'Power': 120,
#                        'Type': 'Dragon'},
#            'Slash': {'Accuracy': 100,
#                      'Description': 'The target is attacked with a slash of '
#                                     'claws or blades. Critical hits land more '
#                                     'easily.',
#                      'Effect %': '--',
#                      'Level': 29,
#                      'PP': 20,
#                      'Power': 70,
#                      'Type': 'Normal'},
#            'Thunder': {'Accuracy': 70,
#                        'Description': 'A wicked thunderbolt is dropped on the '
#                                       'target to inflict damage. This may also '
#                                       'leave the target with paralysis.',
#                        'Effect %': 30,
#                        'Level': 71,
#                        'PP': 10,
#                        'Power': 110,
#                        'Type': 'Electric'},
#            'Thunder Fang': {'Accuracy': 95,
#                             'Description': 'The user bites with electrified '
#                                            'fangs. This may also make the '
#                                            'target flinch or leave it with '
#                                            'paralysis.',
#                             'Effect %': 20,
#                             'Level': '—',
#                             'PP': 15,
#                             'Power': 65,
#                             'Type': 'Electric'},
#            'Thunderbolt': {'Accuracy': 100,
#                            'Description': 'A strong electric blast crashes '
#                                           'down on the target. This may also '
#                                           'leave the target with paralysis.',
#                            'Effect %': 10,
#                            'Level': 15,
#                            'PP': 15,
#                            'Power': 90,
#                            'Type': 'Electric'},
#            'Zen Headbutt': {'Accuracy': 90,
#                             'Description': 'The user focuses its willpower to '
#                                            'its head and attacks the target. '
#                                            'This may also make the target '
#                                            'flinch.',
#                             'Effect %': 20,
#                             'Level': 36,
#                             'PP': 15,
#                             'Power': 80,
#                             'Type': 'Psychic'}},
#  'Name': 'Zekrom',
#  'Sp. Attack': 120,
#  'Sp. Defense': 100,
#  'Speed': 90,
#  'Total': 680,
#  'Type 1': 'Dragon',
#  'Type 2': 'Electric',
#  'Weight (kg)': 345,
#  'Weight (lbs)': 760.6,
#  '_id': ObjectId('6759b84a0aaca17d8a11f7ab')}
# {'Abilities': ['Pressure', 'Teravolt', 'Turboblaze'],
#  'Attack': 130,
#  'Capture Rate': 3,
#  'Category': 'Boundary Pokémon',
#  'Defense': 90,
#  'Egg Steps': 30720,
#  'Exp Group': 'Slow',
#  'HP': 125,
#  'Height (ft)': '9\'10"',
#  'Height (m)': 3,
#  'Id': '646',
#  'Moves': {'Ancient Power': {'Accuracy': 100,
#                              'Description': 'The user attacks with a '
#                                             'prehistoric power. This may also '
#                                             "raise all the user's stats at "
#                                             'once.',
#                              'Effect %': 10,
#                              'Level': 8,
#                              'PP': 5,
#                              'Power': 60,
#                              'Type': 'Rock'},
#            'Blizzard': {'Accuracy': 70,
#                         'Description': 'A howling blizzard is summoned to '
#                                        'strike opposing Pokémon. This may also '
#                                        'leave the opposing Pokémon frozen.',
#                         'Effect %': 10,
#                         'Level': 71,
#                         'PP': 5,
#                         'Power': 110,
#                         'Type': 'Ice'},
#            'Dragon Breath': {'Accuracy': 100,
#                              'Description': 'The user exhales a mighty gust '
#                                             'that inflicts damage. This may '
#                                             'also leave the target with '
#                                             'paralysis.',
#                              'Effect %': 30,
#                              'Level': 22,
#                              'PP': 20,
#                              'Power': 60,
#                              'Type': 'Dragon'},
#            'Dragon Pulse': {'Accuracy': 100,
#                             'Description': 'The target is attacked with a '
#                                            "shock wave generated by the user's "
#                                            'gaping mouth.',
#                             'Effect %': '--',
#                             'Level': 50,
#                             'PP': 10,
#                             'Power': 85,
#                             'Type': 'Dragon'},
#            'Dragon Rage': {'Accuracy': 100,
#                            'Description': 'This attack hits the target with a '
#                                           'shock wave of pure rage. This '
#                                           'attack always inflicts 40 HP '
#                                           'damage.',
#                            'Effect %': '--',
#                            'Level': '—',
#                            'PP': 10,
#                            'Power': '??',
#                            'Type': 'Dragon'},
#            'Endeavor': {'Accuracy': 100,
#                         'Description': 'This attack move cuts down the '
#                                        "target's HP to equal the user's HP.",
#                         'Effect %': '--',
#                         'Level': 64,
#                         'PP': 5,
#                         'Power': '??',
#                         'Type': 'Normal'},
#            'Glaciate': {'Accuracy': 95,
#                         'Description': 'The user attacks by blowing freezing '
#                                        'cold air at opposing Pokémon. This '
#                                        'lowers their Speed stat.',
#                         'Effect %': 100,
#                         'Level': 43,
#                         'PP': 10,
#                         'Power': 65,
#                         'Type': 'Ice'},
#            'Hyper Voice': {'Accuracy': 100,
#                            'Description': 'The user lets loose a horribly '
#                                           'echoing shout with the power to '
#                                           'inflict damage.',
#                            'Effect %': '--',
#                            'Level': 85,
#                            'PP': 10,
#                            'Power': 90,
#                            'Type': 'Normal'},
#            'Ice Beam': {'Accuracy': 100,
#                         'Description': 'The target is struck with an icy-cold '
#                                        'beam of energy. This may also leave '
#                                        'the target frozen.',
#                         'Effect %': 10,
#                         'Level': 15,
#                         'PP': 10,
#                         'Power': 90,
#                         'Type': 'Ice'},
#            'Icy Wind': {'Accuracy': 95,
#                         'Description': 'The user attacks with a gust of '
#                                        'chilled air. This also lowers the '
#                                        "opposing Pokémon's Speed stats.",
#                         'Effect %': 100,
#                         'Level': '—',
#                         'PP': 15,
#                         'Power': 55,
#                         'Type': 'Ice'},
#            'Imprison': {'Accuracy': '--',
#                         'Description': 'If opposing Pokémon know any move also '
#                                        'known by the user, they are prevented '
#                                        'from using it.',
#                         'Effect %': '--',
#                         'Level': 57,
#                         'PP': 10,
#                         'Power': '--',
#                         'Type': 'Psychic'},
#            'Outrage': {'Accuracy': 100,
#                        'Description': 'The user rampages and attacks for two '
#                                       'to three turns. The user then becomes '
#                                       'confused.',
#                        'Effect %': '--',
#                        'Level': 78,
#                        'PP': 10,
#                        'Power': 120,
#                        'Type': 'Dragon'},
#            'Scary Face': {'Accuracy': 100,
#                           'Description': 'The user frightens the target with a '
#                                          'scary face to harshly lower its '
#                                          'Speed stat.',
#                           'Effect %': '--',
#                           'Level': 36,
#                           'PP': 10,
#                           'Power': '--',
#                           'Type': 'Normal'},
#            'Slash': {'Accuracy': 100,
#                      'Description': 'The target is attacked with a slash of '
#                                     'claws or blades. Critical hits land more '
#                                     'easily.',
#                      'Effect %': '--',
#                      'Level': 29,
#                      'PP': 20,
#                      'Power': 70,
#                      'Type': 'Normal'}},
#  'Name': 'Kyurem',
#  'Sp. Attack': 130,
#  'Sp. Defense': 90,
#  'Speed': 95,
#  'Total': 660,
#  'Type 1': 'Dragon',
#  'Type 2': 'Ice',
#  'Weight (kg)': 325,
#  'Weight (lbs)': 716.5,
#  '_id': ObjectId('6759b84a0aaca17d8a11f7ad')}
# {'Abilities': ['Overgrow', 'Bulletproof'],
#  'Attack': 107,
#  'Capture Rate': 45,
#  'Category': 'Spiny Armor Pokémon',
#  'Defense': 122,
#  'Egg Steps': 5120,
#  'Exp Group': 'Medium Slow',
#  'HP': 88,
#  'Height (ft)': '5\'03"',
#  'Height (m)': 1.6,
#  'Id': '652',
#  'Moves': {'Belly Drum': {'Accuracy': '--',
#                           'Description': 'The user maximizes its Attack stat '
#                                          'in exchange for HP equal to half its '
#                                          'max HP.',
#                           'Effect %': '--',
#                           'Level': '—',
#                           'PP': 10,
#                           'Power': '--',
#                           'Type': 'Normal'},
#            'Bite': {'Accuracy': 100,
#                     'Description': 'The target is bitten with viciously sharp '
#                                    'fangs. This may also make the target '
#                                    'flinch.',
#                     'Effect %': 30,
#                     'Level': 11,
#                     'PP': 25,
#                     'Power': 60,
#                     'Type': 'Dark'},
#            'Body Slam': {'Accuracy': 100,
#                          'Description': 'The user drops onto the target with '
#                                         'its full body weight. This may also '
#                                         'leave the target with paralysis.',
#                          'Effect %': 30,
#                          'Level': 54,
#                          'PP': 15,
#                          'Power': 85,
#                          'Type': 'Normal'},
#            'Bulk Up': {'Accuracy': '--',
#                        'Description': 'The user tenses its muscles to bulk up '
#                                       'its body, raising both its Attack and '
#                                       'Defense stats.',
#                        'Effect %': '--',
#                        'Level': 48,
#                        'PP': 20,
#                        'Power': '--',
#                        'Type': 'Fighting'},
#            'Feint': {'Accuracy': 100,
#                      'Description': 'This attack hits a target using a move '
#                                     'such as Protect or Detect. This also '
#                                     'lifts the effects of those moves.',
#                      'Effect %': '--',
#                      'Level': '—',
#                      'PP': 10,
#                      'Power': 30,
#                      'Type': 'Normal'},
#            'Giga Impact': {'Accuracy': 90,
#                            'Description': 'The user charges at the target '
#                                           'using every bit of its power. The '
#                                           "user can't move on the next turn.",
#                            'Effect %': '--',
#                            'Level': 78,
#                            'PP': 5,
#                            'Power': 150,
#                            'Type': 'Normal'},
#            'Growl': {'Accuracy': 100,
#                      'Description': 'The user growls in an endearing way, '
#                                     'making opposing Pokémon less wary. This '
#                                     'lowers their Attack stat.',
#                      'Effect %': '--',
#                      'Level': '—',
#                      'PP': 40,
#                      'Power': '--',
#                      'Type': 'Normal'},
#            'Hammer Arm': {'Accuracy': 90,
#                           'Description': 'The user swings and hits with its '
#                                          'strong, heavy fist. It lowers the '
#                                          "user's Speed, however.",
#                           'Effect %': 100,
#                           'Level': 72,
#                           'PP': 10,
#                           'Power': 100,
#                           'Type': 'Fighting'},
#            'Leech Seed': {'Accuracy': 90,
#                           'Description': 'A seed is planted on the target. It '
#                                          'steals some HP from the target every '
#                                          'turn.',
#                           'Effect %': '--',
#                           'Level': 15,
#                           'PP': 10,
#                           'Power': '--',
#                           'Type': 'Grass'},
#            'Mud Shot': {'Accuracy': 95,
#                         'Description': 'The user attacks by hurling a blob of '
#                                        'mud at the target. This also lowers '
#                                        "the target's Speed stat.",
#                         'Effect %': 100,
#                         'Level': 41,
#                         'PP': 15,
#                         'Power': 55,
#                         'Type': 'Ground'},
#            'Needle Arm': {'Accuracy': 100,
#                           'Description': 'The user attacks by wildly swinging '
#                                          'its thorny arms. This may also make '
#                                          'the target flinch.',
#                           'Effect %': 30,
#                           'Level': '—',
#                           'PP': 15,
#                           'Power': 60,
#                           'Type': 'Grass'},
#            'Pain Split': {'Accuracy': '--',
#                           'Description': "The user adds its HP to the target's "
#                                          'HP, then equally shares the combined '
#                                          'HP with the target.',
#                           'Effect %': '--',
#                           'Level': 60,
#                           'PP': 20,
#                           'Power': '--',
#                           'Type': 'Normal'},
#            'Pin Missile': {'Accuracy': 95,
#                            'Description': 'Sharp spikes are shot at the target '
#                                           'in rapid succession. They hit two '
#                                           'to five times in a row.',
#                            'Effect %': '--',
#                            'Level': 19,
#                            'PP': 20,
#                            'Power': 25,
#                            'Type': 'Bug'},
#            'Rollout': {'Accuracy': 90,
#                        'Description': 'The user continually rolls into the '
#                                       'target over five turns. It becomes more '
#                                       'powerful each time it hits.',
#                        'Effect %': '--',
#                        'Level': 8,
#                        'PP': 20,
#                        'Power': 30,
#                        'Type': 'Rock'},
#            'Seed Bomb': {'Accuracy': 100,
#                          'Description': 'The user slams a barrage of '
#                                         'hard-shelled seeds down on the target '
#                                         'from above.',
#                          'Effect %': '--',
#                          'Level': 35,
#                          'PP': 15,
#                          'Power': 80,
#                          'Type': 'Grass'},
#            'Spiky Shield': {'Accuracy': '--',
#                             'Description': 'In addition to protecting the user '
#                                            'from attacks, this move also '
#                                            'damages any attacker who makes '
#                                            'direct contact.',
#                             'Effect %': '--',
#                             'Level': 'Evolve',
#                             'PP': 10,
#                             'Power': '--',
#                             'Type': 'Grass'},
#            'Tackle': {'Accuracy': 100,
#                       'Description': 'A physical attack in which the user '
#                                      'charges and slams into the target with '
#                                      'its whole body.',
#                       'Effect %': '--',
#                       'Level': '—',
#                       'PP': 35,
#                       'Power': 40,
#                       'Type': 'Normal'},
#            'Take Down': {'Accuracy': 85,
#                          'Description': 'A reckless, full-body charge attack '
#                                         'for slamming into the target. This '
#                                         'also damages the user a little.',
#                          'Effect %': '--',
#                          'Level': 29,
#                          'PP': 20,
#                          'Power': 90,
#                          'Type': 'Normal'},
#            'Vine Whip': {'Accuracy': 100,
#                          'Description': 'The target is struck with slender, '
#                                         'whiplike vines to inflict damage.',
#                          'Effect %': '--',
#                          'Level': 5,
#                          'PP': 25,
#                          'Power': 45,
#                          'Type': 'Grass'},
#            'Wood Hammer': {'Accuracy': 100,
#                            'Description': 'The user slams its rugged body into '
#                                           'the target to attack. This also '
#                                           'damages the user quite a lot.',
#                            'Effect %': '--',
#                            'Level': 66,
#                            'PP': 15,
#                            'Power': 120,
#                            'Type': 'Grass'}},
#  'Name': 'Chesnaught',
#  'Sp. Attack': 74,
#  'Sp. Defense': 75,
#  'Speed': 64,
#  'Total': 530,
#  'Type 1': 'Grass',
#  'Type 2': 'Fighting',
#  'Weight (kg)': 90,
#  'Weight (lbs)': 198.4,
#  '_id': ObjectId('6759b84a0aaca17d8a11f7b3')}
# {'Abilities': ['Sap Sipper', 'Grass Pelt'],
#  'Attack': 100,
#  'Capture Rate': 45,
#  'Category': 'Mount Pokémon',
#  'Defense': 62,
#  'Egg Steps': 5120,
#  'Exp Group': 'Medium Fast',
#  'HP': 123,
#  'Height (ft)': '5\'07"',
#  'Height (m)': 1.7,
#  'Id': '673',
#  'Moves': {'Aerial Ace': {'Accuracy': '--',
#                           'Description': 'The user confounds the target with '
#                                          'speed, then slashes. This attack '
#                                          'never misses.',
#                           'Effect %': '--',
#                           'Level': 'Evolve',
#                           'PP': 20,
#                           'Power': 60,
#                           'Type': 'Flying'},
#            'Bulk Up': {'Accuracy': '--',
#                        'Description': 'The user tenses its muscles to bulk up '
#                                       'its body, raising both its Attack and '
#                                       'Defense stats.',
#                        'Effect %': '--',
#                        'Level': 34,
#                        'PP': 20,
#                        'Power': '--',
#                        'Type': 'Fighting'},
#            'Bulldoze': {'Accuracy': 100,
#                         'Description': 'The user strikes everything around it '
#                                        'by stomping down on the ground. This '
#                                        'lowers the Speed stat of those hit.',
#                         'Effect %': 100,
#                         'Level': 26,
#                         'PP': 20,
#                         'Power': 60,
#                         'Type': 'Ground'},
#            'Double-Edge': {'Accuracy': 100,
#                            'Description': 'A reckless, life-risking tackle. '
#                                           'This also damages the user quite a '
#                                           'lot.',
#                            'Effect %': '--',
#                            'Level': 40,
#                            'PP': 15,
#                            'Power': 120,
#                            'Type': 'Normal'},
#            'Earthquake': {'Accuracy': 100,
#                           'Description': 'The user sets off an earthquake that '
#                                          'strikes every Pokémon around it.',
#                           'Effect %': '--',
#                           'Level': '—',
#                           'PP': 10,
#                           'Power': 100,
#                           'Type': 'Ground'},
#            'Growth': {'Accuracy': '--',
#                       'Description': "The user's body grows all at once, "
#                                      'raising the Attack and Sp. Atk stats.',
#                       'Effect %': '--',
#                       'Level': '—',
#                       'PP': 20,
#                       'Power': '--',
#                       'Type': 'Normal'},
#            'Horn Leech': {'Accuracy': 100,
#                           'Description': "The user drains the target's energy "
#                                          "with its horns. The user's HP is "
#                                          'restored by half the damage taken by '
#                                          'the target.',
#                           'Effect %': '--',
#                           'Level': 47,
#                           'PP': 10,
#                           'Power': 75,
#                           'Type': 'Grass'},
#            'Leaf Blade': {'Accuracy': 100,
#                           'Description': 'The user handles a sharp leaf like a '
#                                          'sword and attacks by cutting its '
#                                          'target. Critical hits land more '
#                                          'easily.',
#                           'Effect %': '--',
#                           'Level': 55,
#                           'PP': 15,
#                           'Power': 90,
#                           'Type': 'Grass'},
#            'Leech Seed': {'Accuracy': 90,
#                           'Description': 'A seed is planted on the target. It '
#                                          'steals some HP from the target every '
#                                          'turn.',
#                           'Effect %': '--',
#                           'Level': 12,
#                           'PP': 10,
#                           'Power': '--',
#                           'Type': 'Grass'},
#            'Milk Drink': {'Accuracy': '--',
#                           'Description': 'The user restores its own HP by up '
#                                          'to half of its max HP.',
#                           'Effect %': '--',
#                           'Level': 58,
#                           'PP': 10,
#                           'Power': '--',
#                           'Type': 'Normal'},
#            'Razor Leaf': {'Accuracy': 95,
#                           'Description': 'Sharp-edged leaves are launched to '
#                                          'slash at the opposing Pokémon. '
#                                          'Critical hits land more easily.',
#                           'Effect %': '--',
#                           'Level': 13,
#                           'PP': 25,
#                           'Power': 55,
#                           'Type': 'Grass'},
#            'Seed Bomb': {'Accuracy': 100,
#                          'Description': 'The user slams a barrage of '
#                                         'hard-shelled seeds down on the target '
#                                         'from above.',
#                          'Effect %': '--',
#                          'Level': 30,
#                          'PP': 15,
#                          'Power': 80,
#                          'Type': 'Grass'},
#            'Synthesis': {'Accuracy': '--',
#                          'Description': 'The user restores its own HP. The '
#                                         'amount of HP regained varies with the '
#                                         'weather.',
#                          'Effect %': '--',
#                          'Level': 20,
#                          'PP': 5,
#                          'Power': '--',
#                          'Type': 'Grass'},
#            'Tackle': {'Accuracy': 100,
#                       'Description': 'A physical attack in which the user '
#                                      'charges and slams into the target with '
#                                      'its whole body.',
#                       'Effect %': '--',
#                       'Level': '—',
#                       'PP': 35,
#                       'Power': 40,
#                       'Type': 'Normal'},
#            'Tail Whip': {'Accuracy': 100,
#                          'Description': 'The user wags its tail cutely, making '
#                                         'opposing Pokémon less wary and '
#                                         'lowering their Defense stat.',
#                          'Effect %': '--',
#                          'Level': 9,
#                          'PP': 30,
#                          'Power': '--',
#                          'Type': 'Normal'},
#            'Take Down': {'Accuracy': 85,
#                          'Description': 'A reckless, full-body charge attack '
#                                         'for slamming into the target. This '
#                                         'also damages the user a little.',
#                          'Effect %': '--',
#                          'Level': 22,
#                          'PP': 20,
#                          'Power': 90,
#                          'Type': 'Normal'},
#            'Vine Whip': {'Accuracy': 100,
#                          'Description': 'The target is struck with slender, '
#                                         'whiplike vines to inflict damage.',
#                          'Effect %': '--',
#                          'Level': 7,
#                          'PP': 25,
#                          'Power': 45,
#                          'Type': 'Grass'},
#            'Worry Seed': {'Accuracy': 100,
#                           'Description': 'A seed that causes worry is planted '
#                                          'on the target. It prevents sleep by '
#                                          "making the target's Ability "
#                                          'Insomnia.',
#                           'Effect %': '--',
#                           'Level': 16,
#                           'PP': 10,
#                           'Power': '--',
#                           'Type': 'Grass'}},
#  'Name': 'Gogoat',
#  'Sp. Attack': 97,
#  'Sp. Defense': 81,
#  'Speed': 68,
#  'Total': 531,
#  'Type 1': 'Grass',
#  'Type 2': 'None',
#  'Weight (kg)': 91,
#  'Weight (lbs)': 200.6,
#  '_id': ObjectId('6759b84a0aaca17d8a11f7c8')}
# {'Abilities': ['No Guard'],
#  'Attack': 110,
#  'Capture Rate': 90,
#  'Category': 'Sword Pokémon',
#  'Defense': 150,
#  'Egg Steps': 5120,
#  'Exp Group': 'Medium Fast',
#  'HP': 59,
#  'Height (ft)': '2\'07"',
#  'Height (m)': 0.8,
#  'Id': '680',
#  'Moves': {'Aerial Ace': {'Accuracy': '--',
#                           'Description': 'The user confounds the target with '
#                                          'speed, then slashes. This attack '
#                                          'never misses.',
#                           'Effect %': '--',
#                           'Level': 22,
#                           'PP': 20,
#                           'Power': 60,
#                           'Type': 'Flying'},
#            'Autotomize': {'Accuracy': '--',
#                           'Description': 'The user sheds part of its body to '
#                                          'make itself lighter and sharply '
#                                          'raise its Speed stat.',
#                           'Effect %': '--',
#                           'Level': 18,
#                           'PP': 15,
#                           'Power': '--',
#                           'Type': 'Steel'},
#            'Fury Cutter': {'Accuracy': 95,
#                            'Description': 'The target is slashed with scythes '
#                                           'or claws. This attack becomes more '
#                                           'powerful if it hits in succession.',
#                            'Effect %': '--',
#                            'Level': 5,
#                            'PP': 20,
#                            'Power': 40,
#                            'Type': 'Bug'},
#            'Iron Defense': {'Accuracy': '--',
#                             'Description': "The user hardens its body's "
#                                            'surface like iron, sharply raising '
#                                            'its Defense stat.',
#                             'Effect %': '--',
#                             'Level': 32,
#                             'PP': 15,
#                             'Power': '--',
#                             'Type': 'Steel'},
#            'Iron Head': {'Accuracy': 100,
#                          'Description': 'The user slams the target with its '
#                                         'steel-hard head. This may also make '
#                                         'the target flinch.',
#                          'Effect %': 30,
#                          'Level': 45,
#                          'PP': 15,
#                          'Power': 80,
#                          'Type': 'Steel'},
#            'Metal Sound': {'Accuracy': 85,
#                            'Description': 'A horrible sound like scraping '
#                                           "metal harshly lowers the target's "
#                                           'Sp. Def stat.',
#                            'Effect %': '--',
#                            'Level': 8,
#                            'PP': 40,
#                            'Power': '--',
#                            'Type': 'Steel'},
#            'Night Slash': {'Accuracy': 100,
#                            'Description': 'The user slashes the target the '
#                                           'instant an opportunity arises. '
#                                           'Critical hits land more easily.',
#                            'Effect %': '--',
#                            'Level': 36,
#                            'PP': 15,
#                            'Power': 70,
#                            'Type': 'Dark'},
#            'Power Trick': {'Accuracy': '--',
#                            'Description': 'The user employs its psychic power '
#                                           'to switch its Attack stat with its '
#                                           'Defense stat.',
#                            'Effect %': '--',
#                            'Level': 41,
#                            'PP': 10,
#                            'Power': '--',
#                            'Type': 'Psychic'},
#            'Pursuit': {'Accuracy': 100,
#                        'Description': 'The power of this attack move is '
#                                       "doubled if it's used on a target that's "
#                                       'switching out of battle.',
#                        'Effect %': '--',
#                        'Level': 13,
#                        'PP': 20,
#                        'Power': 40,
#                        'Type': 'Dark'},
#            'Retaliate': {'Accuracy': 100,
#                          'Description': 'The user gets revenge for a fainted '
#                                         'ally. If an ally fainted in the '
#                                         "previous turn, this move's power is "
#                                         'increased.',
#                          'Effect %': '--',
#                          'Level': 26,
#                          'PP': 5,
#                          'Power': 70,
#                          'Type': 'Normal'},
#            'Sacred Sword': {'Accuracy': 100,
#                             'Description': 'The user attacks by slicing with a '
#                                            "long horn. The target's stat "
#                                            "changes don't affect this attack's "
#                                            'damage.',
#                             'Effect %': '--',
#                             'Level': 51,
#                             'PP': 15,
#                             'Power': 90,
#                             'Type': 'Fighting'},
#            'Shadow Sneak': {'Accuracy': 100,
#                             'Description': 'The user extends its shadow and '
#                                            'attacks the target from behind. '
# ...
#                           'Type': 'Poison'},
#            'Double Iron Bash': {'Accuracy': 100,
#                                 'Description': 'The user rotates, centering '
#                                                'the hex nut in its chest, and '
#                                                'then strikes with its arms '
#                                                'twice in a row. This may also '
#                                                'make the target flinch.',
#                                 'Effect %': 30,
#                                 'Level': 72,
#                                 'PP': 5,
#                                 'Power': 60,
#                                 'Type': 'Steel'},
#            'Flash Cannon': {'Accuracy': 100,
#                             'Description': 'The user gathers all its light '
#                                            'energy and releases it all at '
#                                            'once. This may also lower the '
#                                            "target's Sp. Def stat.",
#                             'Effect %': 10,
#                             'Level': 45,
#                             'PP': 10,
#                             'Power': 80,
#                             'Type': 'Steel'},
#            'Harden': {'Accuracy': '--',
#                       'Description': 'The user stiffens all the muscles in its '
#                                      'body to raise its Defense stat.',
#                       'Effect %': '--',
#                       'Level': '—',
#                       'PP': 30,
#                       'Power': '--',
#                       'Type': 'Normal'},
#            'Headbutt': {'Accuracy': 100,
#                         'Description': 'The user sticks out its head and '
#                                        'attacks by charging straight into the '
#                                        'target. This may also make the target '
#                                        'flinch.',
#                         'Effect %': 30,
#                         'Level': '—',
#                         'PP': 15,
#                         'Power': 70,
#                         'Type': 'Normal'},
#            'Hyper Beam': {'Accuracy': 90,
#                           'Description': 'The target is attacked with a '
#                                          "powerful beam. The user can't move "
#                                          'on the next turn.',
#                           'Effect %': '--',
#                           'Level': 90,
#                           'PP': 5,
#                           'Power': 150,
#                           'Type': 'Normal'},
#            'Mega Punch': {'Accuracy': 85,
#                           'Description': 'The target is slugged by a punch '
#                                          'thrown with muscle-packed power.',
#                           'Effect %': '--',
#                           'Level': 54,
#                           'PP': 20,
#                           'Power': 80,
#                           'Type': 'Normal'},
#            'Protect': {'Accuracy': '--',
#                        'Description': 'Enables the user to evade all attacks. '
#                                       'Its chance of failing rises if it is '
#                                       'used in succession.',
#                        'Effect %': '--',
#                        'Level': 63,
#                        'PP': 10,
#                        'Power': '--',
#                        'Type': 'Normal'},
#            'Superpower': {'Accuracy': 100,
#                           'Description': 'The user attacks the target with '
#                                          'great power. However, this also '
#                                          "lowers the user's Attack and Defense "
#                                          'stats.',
#                           'Effect %': 100,
#                           'Level': 81,
#                           'PP': 5,
#                           'Power': 120,
#                           'Type': 'Fighting'},
#            'Tail Whip': {'Accuracy': 100,
#                          'Description': 'The user wags its tail cutely, making '
#                                         'opposing Pokémon less wary and '
#                                         'lowering their Defense stat.',
#                          'Effect %': '--',
#                          'Level': 9,
#                          'PP': 30,
#                          'Power': '--',
#                          'Type': 'Normal'},
#            'Thunder Punch': {'Accuracy': 100,
#                              'Description': 'The target is punched with an '
#                                             'electrified fist. This may also '
#                                             'leave the target with paralysis.',
#                              'Effect %': 10,
#                              'Level': '—',
#                              'PP': 15,
#                              'Power': 75,
#                              'Type': 'Electric'},
#            'Thunder Shock': {'Accuracy': 100,
#                              'Description': 'A jolt of electricity crashes '
#                                             'down on the target to inflict '
#                                             'damage. This may also leave the '
#                                             'target with paralysis.',
#                              'Effect %': 10,
#                              'Level': 27,
#                              'PP': 30,
#                              'Power': 40,
#                              'Type': 'Electric'},
#            'Thunder Wave': {'Accuracy': 90,
#                             'Description': 'The user launches a weak jolt of '
#                                            'electricity that paralyzes the '
#                                            'target.',
#                             'Effect %': '--',
#                             'Level': 18,
#                             'PP': 20,
#                             'Power': '--',
#                             'Type': 'Electric'}},
#  'Name': 'Melmetal',
#  'Sp. Attack': 80,
#  'Sp. Defense': 65,
#  'Speed': 34,
#  'Total': 600,
#  'Type 1': 'Steel',
#  'Type 2': 'None',
#  'Weight (kg)': 800,
#  'Weight (lbs)': 1763.7,
#  '_id': ObjectId('6759b84a0aaca17d8a11f84f')}
# {'Abilities': ['Beast Boost'],
#  'Attack': 101,
#  'Capture Rate': 15,
#  'Category': 'Junkivore Pokémon',
#  'Defense': 53,
#  'Egg Steps': 30720,
#  'Exp Group': 'Slow',
#  'HP': 223,
#  'Height (ft)': '18\'01"',
#  'Height (m)': 5.5,
#  'Id': '799',
#  'Moves': {'Belch': {'Accuracy': 90,
#                      'Description': 'The user lets out a damaging belch at the '
#                                     'target. The user must eat a held Berry to '
#                                     'use this move.',
#                      'Effect %': '--',
#                      'Level': '—',
#                      'PP': 10,
#                      'Power': 120,
#                      'Type': 'Poison'},
#            'Bite': {'Accuracy': 100,
#                     'Description': 'The target is bitten with viciously sharp '
#                                    'fangs. This may also make the target '
#                                    'flinch.',
#                     'Effect %': 30,
#                     'Level': 40,
#                     'PP': 25,
#                     'Power': 60,
#                     'Type': 'Dark'},
#            'Brutal Swing': {'Accuracy': 100,
#                             'Description': 'The user swings its body around '
#                                            'violently to inflict damage on '
#                                            'everything in its vicinity.',
#                             'Effect %': '--',
#                             'Level': 7,
#                             'PP': 20,
#                             'Power': 60,
#                             'Type': 'Dark'},
#            'Crunch': {'Accuracy': 100,
#                       'Description': 'The user crunches up the target with '
#                                      'sharp fangs. This may also lower the '
#                                      "target's Defense stat.",
#                       'Effect %': 20,
#                       'Level': 31,
#                       'PP': 15,
#                       'Power': 80,
#                       'Type': 'Dark'},
#            'Dragon Rage': {'Accuracy': 100,
#                            'Description': 'This attack hits the target with a '
#                                           'shock wave of pure rage. This '
#                                           'attack always inflicts 40 HP '
#                                           'damage.',
#                            'Effect %': '--',
#                            'Level': '—',
#                            'PP': 10,
#                            'Power': '??',
#                            'Type': 'Dragon'},
#            'Dragon Rush': {'Accuracy': 75,
#                            'Description': 'The user tackles the target while '
#                                           'exhibiting overwhelming menace. '
#                                           'This may also make the target '
#                                           'flinch.',
#                            'Effect %': 20,
#                            'Level': 67,
#                            'PP': 10,
#                            'Power': 100,
#                            'Type': 'Dragon'},
#            'Dragon Tail': {'Accuracy': 90,
#                            'Description': 'The target is knocked away, and a '
#                                           'different Pokémon is dragged out. '
#                                           'In the wild, this ends a battle '
#                                           'against a single Pokémon.',
#                            'Effect %': '--',
#                            'Level': 19,
#                            'PP': 10,
#                            'Power': 60,
#                            'Type': 'Dragon'},
#            'Gastro Acid': {'Accuracy': 100,
#                            'Description': 'The user hurls up its stomach acids '
#                                           'on the target. The fluid eliminates '
#                                           "the effect of the target's Ability.",
#                            'Effect %': '--',
#                            'Level': 47,
#                            'PP': 10,
#                            'Power': '--',
#                            'Type': 'Poison'},
#            'Hammer Arm': {'Accuracy': 90,
#                           'Description': 'The user swings and hits with its '
#                                          'strong, heavy fist. It lowers the '
#                                          "user's Speed, however.",
#                           'Effect %': 100,
#                           'Level': 37,
#                           'PP': 10,
#                           'Power': 100,
#                           'Type': 'Fighting'},
#            'Heavy Slam': {'Accuracy': 100,
#                           'Description': 'The user slams into the target with '
#                                          'its heavy body. The more the user '
#                                          'outweighs the target, the greater '
#                                          "the move's power.",
#                           'Effect %': '--',
#                           'Level': 53,
#                           'PP': 10,
#                           'Power': '??',
#                           'Type': 'Steel'},
#            'Iron Tail': {'Accuracy': 75,
#                          'Description': 'The target is slammed with a '
#                                         'steel-hard tail. This may also lower '
#                                         "the target's Defense stat.",
#                          'Effect %': 30,
#                          'Level': 23,
#                          'PP': 15,
#                          'Power': 100,
#                          'Type': 'Steel'},
#            'Steamroller': {'Accuracy': 100,
#                            'Description': 'The user crushes its target by '
#                                           'rolling over the target with its '
#                                           'rolled-up body. This may also make '
#                                           'the target flinch.',
#                            'Effect %': 30,
#                            'Level': 13,
#                            'PP': 20,
#                            'Power': 65,
#                            'Type': 'Bug'},
#            'Stockpile': {'Accuracy': '--',
#                          'Description': 'The user charges up power and raises '
#                                         'both its Defense and Sp. Def stats. '
#                                         'The move can be used three times.',
#                          'Effect %': '--',
#                          'Level': '—',
#                          'PP': 20,
#                          'Power': '--',
#                          'Type': 'Normal'},
#            'Stomp': {'Accuracy': 100,
#                      'Description': 'The target is stomped with a big foot. '
#                                     'This may also make the target flinch.',
#                      'Effect %': 30,
#                      'Level': '—',
#                      'PP': 20,
#                      'Power': 65,
#                      'Type': 'Normal'},
#            'Stomping Tantrum': {'Accuracy': 100,
#                                 'Description': 'Driven by frustration, the '
#                                                'user attacks the target. If '
#                                                "the user's previous move has "
#                                                'failed, the power of this move '
#                                                'doubles.',
#                                 'Effect %': '--',
#                                 'Level': 29,
#                                 'PP': 10,
#                                 'Power': 75,
#                                 'Type': 'Ground'},
#            'Swallow': {'Accuracy': '--',
#                        'Description': 'The power stored using the move '
#                                       'Stockpile is absorbed by the user to '
#                                       'heal its HP. Storing more power heals '
#                                       'more HP.',
#                        'Effect %': '--',
#                        'Level': '—',
#                        'PP': 10,
#                        'Power': '--',
#                        'Type': 'Normal'},
#            'Thrash': {'Accuracy': 100,
#                       'Description': 'The user rampages and attacks for two to '
#                                      'three turns. The user then becomes '
#                                      'confused.',
#                       'Effect %': '--',
#                       'Level': 43,
#                       'PP': 10,
#                       'Power': 120,
#                       'Type': 'Normal'},
#            'Wide Guard': {'Accuracy': '--',
#                           'Description': 'The user and its allies are '
#                                          'protected from wide-ranging attacks '
#                                          'for one turn.',
#                           'Effect %': '--',
#                           'Level': '—',
#                           'PP': 10,
#                           'Power': '--',
#                           'Type': 'Rock'},
#            'Wring Out': {'Accuracy': 100,
#                          'Description': 'The user powerfully wrings the '
#                                         'target. The more HP the target has, '
#                                         "the greater the move's power.",
#                          'Effect %': '--',
#                          'Level': 59,
#                          'PP': 5,
#                          'Power': '??',
#                          'Type': 'Normal'}},
#  'Name': 'Guzzlord',
#  'Sp. Attack': 97,
#  'Sp. Defense': 53,
#  'Speed': 43,
#  'Total': 570,
#  'Type 1': 'Dark',
#  'Type 2': 'Dragon',
#  'Weight (kg)': 888,
#  'Weight (lbs)': 1957.7,
#  '_id': ObjectId('6759b84a0aaca17d8a11f850')}

# %% [markdown]
# #Pregunta 4
# Seleccione los pokemones que tienen el movimiento $\texttt{Take Down}$ de nivel 15.
#
# **Hint**: Puede consultar en diccionarios embebidos concatenando las llaves con un punto ".".
#
# Por ejemplo, para un dato:
# ```
# [{
#   a: {
#     b: 'foo'
#   }
# }]
# ```
# se puede consultar por los documentos tal que $\texttt{b}$ sea $\texttt{foo}$, escribiendo $\texttt{collection.find({'a.b': 'foo'})}$.

# %%
import pprint
for pokemon in collection.find({'Moves.Take Down.Level': 15}):
    pprint.pprint(pokemon)
# Out:
# {'Abilities': ['Overgrow', 'Chlorophyll'],
#  'Attack': 49,
#  'Capture Rate': 45,
#  'Category': 'Seed Pokémon',
#  'Defense': 49,
#  'Egg Steps': 5120,
#  'Exp Group': 'Medium Slow',
#  'HP': 45,
#  'Height (ft)': '2\'04"',
#  'Height (m)': 0.7,
#  'Id': '001',
#  'Moves': {'Double-Edge': {'Accuracy': 100,
#                            'Description': 'A reckless, life-risking tackle. '
#                                           'This also damages the user quite a '
#                                           'lot.',
#                            'Effect %': '--',
#                            'Level': 27,
#                            'PP': 15,
#                            'Power': 120,
#                            'Type': 'Normal'},
#            'Growl': {'Accuracy': 100,
#                      'Description': 'The user growls in an endearing way, '
#                                     'making opposing Pokémon less wary. This '
#                                     'lowers their Attack stat.',
#                      'Effect %': '--',
#                      'Level': 3,
#                      'PP': 40,
#                      'Power': '--',
#                      'Type': 'Normal'},
#            'Growth': {'Accuracy': '--',
#                       'Description': "The user's body grows all at once, "
#                                      'raising the Attack and Sp. Atk stats.',
#                       'Effect %': '--',
#                       'Level': 25,
#                       'PP': 20,
#                       'Power': '--',
#                       'Type': 'Normal'},
#            'Poison Powder': {'Accuracy': 75,
#                              'Description': 'The user scatters a cloud of '
#                                             'poisonous dust that poisons the '
#                                             'target.',
#                              'Effect %': '--',
#                              'Level': 13,
#                              'PP': 35,
#                              'Power': '--',
#                              'Type': 'Poison'},
#            'Razor Leaf': {'Accuracy': 95,
#                           'Description': 'Sharp-edged leaves are launched to '
#                                          'slash at the opposing Pokémon. '
#                                          'Critical hits land more easily.',
#                           'Effect %': '--',
#                           'Level': 19,
#                           'PP': 25,
#                           'Power': 55,
#                           'Type': 'Grass'},
#            'Seed Bomb': {'Accuracy': 100,
#                          'Description': 'The user slams a barrage of '
#                                         'hard-shelled seeds down on the target '
#                                         'from above.',
#                          'Effect %': '--',
#                          'Level': 37,
#                          'PP': 15,
#                          'Power': 80,
#                          'Type': 'Grass'},
#            'Sleep Powder': {'Accuracy': 75,
#                             'Description': 'The user scatters a big cloud of '
#                                            'sleep-inducing dust around the '
#                                            'target.',
#                             'Effect %': '--',
#                             'Level': 13,
#                             'PP': 15,
#                             'Power': '--',
#                             'Type': 'Grass'},
#            'Sweet Scent': {'Accuracy': 100,
#                            'Description': 'A sweet scent that harshly lowers '
#                                           "opposing Pokémon's evasiveness.",
#                            'Effect %': '--',
#                            'Level': 21,
#                            'PP': 20,
#                            'Power': '--',
#                            'Type': 'Normal'},
#            'Synthesis': {'Accuracy': '--',
#                          'Description': 'The user restores its own HP. The '
#                                         'amount of HP regained varies with the '
#                                         'weather.',
#                          'Effect %': '--',
#                          'Level': 33,
#                          'PP': 5,
#                          'Power': '--',
#                          'Type': 'Grass'},
#            'Tackle': {'Accuracy': 100,
#                       'Description': 'A physical attack in which the user '
#                                      'charges and slams into the target with '
#                                      'its whole body.',
#                       'Effect %': '--',
#                       'Level': '—',
#                       'PP': 35,
#                       'Power': 40,
#                       'Type': 'Normal'},
#            'Take Down': {'Accuracy': 85,
#                          'Description': 'A reckless, full-body charge attack '
#                                         'for slamming into the target. This '
#                                         'also damages the user a little.',
#                          'Effect %': '--',
#                          'Level': 15,
#                          'PP': 20,
#                          'Power': 90,
#                          'Type': 'Normal'},
#            'Vine Whip': {'Accuracy': 100,
#                          'Description': 'The target is struck with slender, '
#                                         'whiplike vines to inflict damage.',
#                          'Effect %': '--',
#                          'Level': 9,
#                          'PP': 25,
#                          'Power': 45,
#                          'Type': 'Grass'},
#            'Worry Seed': {'Accuracy': 100,
#                           'Description': 'A seed that causes worry is planted '
#                                          'on the target. It prevents sleep by '
#                                          "making the target's Ability "
#                                          'Insomnia.',
#                           'Effect %': '--',
#                           'Level': 31,
#                           'PP': 10,
#                           'Power': '--',
#                           'Type': 'Grass'}},
#  'Name': 'Bulbasaur',
#  'Sp. Attack': 65,
#  'Sp. Defense': 65,
#  'Speed': 45,
#  'Total': 318,
#  'Type 1': 'Grass',
#  'Type 2': 'Poison',
#  'Weight (kg)': 6.9,
#  'Weight (lbs)': 15.2,
#  '_id': ObjectId('6759b84a0aaca17d8a11f528')}
# {'Abilities': ['Overgrow', 'Chlorophyll'],
#  'Attack': 62,
#  'Capture Rate': 45,
#  'Category': 'Seed Pokémon',
#  'Defense': 63,
#  'Egg Steps': 5120,
#  'Exp Group': 'Medium Slow',
#  'HP': 60,
#  'Height (ft)': '3\'03"',
#  'Height (m)': 1,
#  'Id': '002',
#  'Moves': {'Double-Edge': {'Accuracy': 100,
#                            'Description': 'A reckless, life-risking tackle. '
#                                           'This also damages the user quite a '
#                                           'lot.',
#                            'Effect %': '--',
#                            'Level': 31,
#                            'PP': 15,
#                            'Power': 120,
#                            'Type': 'Normal'},
#            'Growl': {'Accuracy': 100,
#                      'Description': 'The user growls in an endearing way, '
#                                     'making opposing Pokémon less wary. This '
#                                     'lowers their Attack stat.',
#                      'Effect %': '--',
#                      'Level': 3,
#                      'PP': 40,
#                      'Power': '--',
#                      'Type': 'Normal'},
#            'Growth': {'Accuracy': '--',
#                       'Description': "The user's body grows all at once, "
#                                      'raising the Attack and Sp. Atk stats.',
#                       'Effect %': '--',
#                       'Level': 28,
#                       'PP': 20,
#                       'Power': '--',
#                       'Type': 'Normal'},
#            'Leech Seed': {'Accuracy': 90,
#                           'Description': 'A seed is planted on the target. It '
#                                          'steals some HP from the target every '
#                                          'turn.',
#                           'Effect %': '--',
#                           'Level': 7,
#                           'PP': 10,
#                           'Power': '--',
#                           'Type': 'Grass'},
#            'Poison Powder': {'Accuracy': 75,
#                              'Description': 'The user scatters a cloud of '
#                                             'poisonous dust that poisons the '
#                                             'target.',
#                              'Effect %': '--',
#                              'Level': 13,
#                              'PP': 35,
#                              'Power': '--',
#                              'Type': 'Poison'},
#            'Razor Leaf': {'Accuracy': 95,
#                           'Description': 'Sharp-edged leaves are launched to '
#                                          'slash at the opposing Pokémon. '
#                                          'Critical hits land more easily.',
#                           'Effect %': '--',
#                           'Level': 20,
#                           'PP': 25,
#                           'Power': 55,
#                           'Type': 'Grass'},
#            'Sleep Powder': {'Accuracy': 75,
#                             'Description': 'The user scatters a big cloud of '
#                                            'sleep-inducing dust around the '
#                                            'target.',
#                             'Effect %': '--',
#                             'Level': 13,
#                             'PP': 15,
#                             'Power': '--',
#                             'Type': 'Grass'},
#            'Solar Beam': {'Accuracy': 100,
#                           'Description': 'In this two-turn attack, the user '
#                                          'gathers light, then blasts a bundled '
#                                          'beam on the next turn.',
#                           'Effect %': '--',
#                           'Level': 44,
#                           'PP': 10,
#                           'Power': 120,
#                           'Type': 'Grass'},
#            'Sweet Scent': {'Accuracy': 100,
#                            'Description': 'A sweet scent that harshly lowers '
#                                           "opposing Pokémon's evasiveness.",
#                            'Effect %': '--',
#                            'Level': 23,
#                            'PP': 20,
#                            'Power': '--',
#                            'Type': 'Normal'},
#            'Synthesis': {'Accuracy': '--',
#                          'Description': 'The user restores its own HP. The '
#                                         'amount of HP regained varies with the '
#                                         'weather.',
#                          'Effect %': '--',
#                          'Level': 39,
#                          'PP': 5,
#                          'Power': '--',
#                          'Type': 'Grass'},
#            'Tackle': {'Accuracy': 100,
#                       'Description': 'A physical attack in which the user '
#                                      'charges and slams into the target with '
#                                      'its whole body.',
#                       'Effect %': '--',
#                       'Level': '—',
#                       'PP': 35,
#                       'Power': 40,
#                       'Type': 'Normal'},
#            'Take Down': {'Accuracy': 85,
#                          'Description': 'A reckless, full-body charge attack '
#                                         'for slamming into the target. This '
#                                         'also damages the user a little.',
#                          'Effect %': '--',
#                          'Level': 15,
#                          'PP': 20,
#                          'Power': 90,
#                          'Type': 'Normal'},
#            'Vine Whip': {'Accuracy': 100,
#                          'Description': 'The target is struck with slender, '
#                                         'whiplike vines to inflict damage.',
#                          'Effect %': '--',
#                          'Level': 9,
#                          'PP': 25,
#                          'Power': 45,
#                          'Type': 'Grass'},
#            'Worry Seed': {'Accuracy': 100,
#                           'Description': 'A seed that causes worry is planted '
#                                          'on the target. It prevents sleep by '
#                                          "making the target's Ability "
#                                          'Insomnia.',
#                           'Effect %': '--',
#                           'Level': 36,
#                           'PP': 10,
#                           'Power': '--',
#                           'Type': 'Grass'}},
#  'Name': 'Ivysaur',
#  'Sp. Attack': 80,
#  'Sp. Defense': 80,
#  'Speed': 60,
#  'Total': 405,
#  'Type 1': 'Grass',
#  'Type 2': 'Poison',
#  'Weight (kg)': 13,
#  'Weight (lbs)': 28.7,
#  '_id': ObjectId('6759b84a0aaca17d8a11f529')}
# {'Abilities': ['Overgrow', 'Chlorophyll'],
#  'Attack': 82,
#  'Capture Rate': 45,
#  'Category': 'Seed Pokémon',
#  'Defense': 83,
#  'Egg Steps': 5120,
#  'Exp Group': 'Medium Slow',
#  'HP': 80,
#  'Height (ft)': '6\'07"',
#  'Height (m)': 2,
#  'Id': '003',
#  'Moves': {'Double-Edge': {'Accuracy': 100,
#                            'Description': 'A reckless, life-risking tackle. '
#                                           'This also damages the user quite a '
#                                           'lot.',
#                            'Effect %': '--',
#                            'Level': 31,
#                            'PP': 15,
#                            'Power': 120,
#                            'Type': 'Normal'},
#            'Growl': {'Accuracy': 100,
#                      'Description': 'The user growls in an endearing way, '
#                                     'making opposing Pokémon less wary. This '
#                                     'lowers their Attack stat.',
#                      'Effect %': '--',
#                      'Level': 3,
#                      'PP': 40,
#                      'Power': '--',
#                      'Type': 'Normal'},
#            'Growth': {'Accuracy': '--',
#                       'Description': "The user's body grows all at once, "
#                                      'raising the Attack and Sp. Atk stats.',
#                       'Effect %': '--',
#                       'Level': 28,
#                       'PP': 20,
#                       'Power': '--',
#                       'Type': 'Normal'},
#            'Leech Seed': {'Accuracy': 90,
#                           'Description': 'A seed is planted on the target. It '
#                                          'steals some HP from the target every '
#                                          'turn.',
#                           'Effect %': '--',
#                           'Level': 7,
#                           'PP': 10,
#                           'Power': '--',
#                           'Type': 'Grass'},
#            'Petal Blizzard': {'Accuracy': 100,
#                               'Description': 'The user stirs up a violent '
#                                              'petal blizzard and attacks '
#                                              'everything around it.',
#                               'Effect %': '--',
#                               'Level': 50,
#                               'PP': 15,
#                               'Power': 90,
#                               'Type': 'Grass'},
#            'Petal Dance': {'Accuracy': 100,
#                            'Description': 'The user attacks the target by '
#                                           'scattering petals for two to three '
#                                           'turns. The user then becomes '
#                                           'confused.',
#                            'Effect %': '--',
#                            'Level': 'Evolve',
#                            'PP': 10,
#                            'Power': 120,
#                            'Type': 'Grass'},
#            'Poison Powder': {'Accuracy': 75,
#                              'Description': 'The user scatters a cloud of '
#                                             'poisonous dust that poisons the '
#                                             'target.',
#                              'Effect %': '--',
#                              'Level': 13,
#                              'PP': 35,
#                              'Power': '--',
#                              'Type': 'Poison'},
#            'Razor Leaf': {'Accuracy': 95,
#                           'Description': 'Sharp-edged leaves are launched to '
#                                          'slash at the opposing Pokémon. '
#                                          'Critical hits land more easily.',
#                           'Effect %': '--',
#                           'Level': 20,
#                           'PP': 25,
#                           'Power': 55,
#                           'Type': 'Grass'},
#            'Sleep Powder': {'Accuracy': 75,
#                             'Description': 'The user scatters a big cloud of '
#                                            'sleep-inducing dust around the '
#                                            'target.',
#                             'Effect %': '--',
#                             'Level': 13,
#                             'PP': 15,
#                             'Power': '--',
#                             'Type': 'Grass'},
#            'Solar Beam': {'Accuracy': 100,
#                           'Description': 'In this two-turn attack, the user '
#                                          'gathers light, then blasts a bundled '
#                                          'beam on the next turn.',
#                           'Effect %': '--',
#                           'Level': 53,
#                           'PP': 10,
#                           'Power': 120,
#                           'Type': 'Grass'},
#            'Sweet Scent': {'Accuracy': 100,
#                            'Description': 'A sweet scent that harshly lowers '
#                                           "opposing Pokémon's evasiveness.",
#                            'Effect %': '--',
#                            'Level': 23,
#                            'PP': 20,
#                            'Power': '--',
#                            'Type': 'Normal'},
#            'Synthesis': {'Accuracy': '--',
#                          'Description': 'The user restores its own HP. The '
#                                         'amount of HP regained varies with the '
#                                         'weather.',
#                          'Effect %': '--',
#                          'Level': 45,
#                          'PP': 5,
#                          'Power': '--',
#                          'Type': 'Grass'},
#            'Tackle': {'Accuracy': 100,
#                       'Description': 'A physical attack in which the user '
#                                      'charges and slams into the target with '
#                                      'its whole body.',
#                       'Effect %': '--',
#                       'Level': '—',
#                       'PP': 35,
#                       'Power': 40,
#                       'Type': 'Normal'},
#            'Take Down': {'Accuracy': 85,
#                          'Description': 'A reckless, full-body charge attack '
#                                         'for slamming into the target. This '
#                                         'also damages the user a little.',
#                          'Effect %': '--',
#                          'Level': 15,
#                          'PP': 20,
#                          'Power': 90,
#                          'Type': 'Normal'},
#            'Vine Whip': {'Accuracy': 100,
#                          'Description': 'The target is struck with slender, '
#                                         'whiplike vines to inflict damage.',
#                          'Effect %': '--',
#                          'Level': 9,
#                          'PP': 25,
#                          'Power': 45,
#                          'Type': 'Grass'},
#            'Worry Seed': {'Accuracy': 100,
#                           'Description': 'A seed that causes worry is planted '
#                                          'on the target. It prevents sleep by '
#                                          "making the target's Ability "
#                                          'Insomnia.',
#                           'Effect %': '--',
#                           'Level': 39,
#                           'PP': 10,
#                           'Power': '--',
#                           'Type': 'Grass'}},
#  'Name': 'Venusaur',
#  'Sp. Attack': 100,
#  'Sp. Defense': 100,
#  'Speed': 80,
#  'Total': 525,
#  'Type 1': 'Grass',
#  'Type 2': 'Poison',
#  'Weight (kg)': 100,
#  'Weight (lbs)': 220.5,
#  '_id': ObjectId('6759b84a0aaca17d8a11f52b')}
# {'Abilities': ['Mold Breaker', 'Sheer Force'],
#  'Attack': 125,
#  'Capture Rate': 45,
#  'Category': 'Head Butt Pokémon',
#  'Defense': 40,
#  'Egg Steps': 7680,
#  'Exp Group': 'Erratic',
#  'HP': 67,
#  'Height (ft)': '2\'11"',
#  'Height (m)': 0.9,
#  'Id': '408',
#  'Moves': {'Ancient Power': {'Accuracy': 100,
#                              'Description': 'The user attacks with a '
#                                             'prehistoric power. This may also '
#                                             "raise all the user's stats at "
#                                             'once.',
#                              'Effect %': 10,
#                              'Level': 33,
#                              'PP': 5,
#                              'Power': 60,
#                              'Type': 'Rock'},
#            'Assurance': {'Accuracy': 100,
#                          'Description': 'If the target has already taken some '
#                                         'damage in the same turn, this '
#                                         "attack's power is doubled.",
#                          'Effect %': '--',
#                          'Level': 24,
#                          'PP': 10,
#                          'Power': 60,
#                          'Type': 'Dark'},
#            'Chip Away': {'Accuracy': 100,
#                          'Description': 'Looking for an opening, the user '
#                                         "strikes consistently. The target's "
#                                         "stat changes don't affect this "
#                                         "attack's damage.",
#                          'Effect %': '--',
#                          'Level': 28,
#                          'PP': 20,
#                          'Power': 70,
#                          'Type': 'Normal'},
#            'Focus Energy': {'Accuracy': '--',
#                             'Description': 'The user takes a deep breath and '
#                                            'focuses so that critical hits land '
#                                            'more easily.',
#                             'Effect %': '--',
#                             'Level': 6,
#                             'PP': 30,
#                             'Power': '--',
#                             'Type': 'Normal'},
#            'Head Smash': {'Accuracy': 80,
#                           'Description': 'The user attacks the target with a '
#                                          'hazardous, full-power headbutt. This '
#                                          'also damages the user terribly.',
#                           'Effect %': '--',
#                           'Level': 46,
#                           'PP': 5,
#                           'Power': 150,
#                           'Type': 'Rock'},
#            'Headbutt': {'Accuracy': 100,
#                         'Description': 'The user sticks out its head and '
#                                        'attacks by charging straight into the '
#                                        'target. This may also make the target '
#                                        'flinch.',
#                         'Effect %': 30,
#                         'Level': '—',
#                         'PP': 15,
#                         'Power': 70,
#                         'Type': 'Normal'},
#            'Leer': {'Accuracy': 100,
#                     'Description': 'The user gives opposing Pokémon an '
#                                    'intimidating leer that lowers the Defense '
#                                    'stat.',
#                     'Effect %': 100,
#                     'Level': '—',
#                     'PP': 30,
#                     'Power': '--',
#                     'Type': 'Normal'},
#            'Pursuit': {'Accuracy': 100,
#                        'Description': 'The power of this attack move is '
#                                       "doubled if it's used on a target that's "
#                                       'switching out of battle.',
#                        'Effect %': '--',
#                        'Level': 10,
#                        'PP': 20,
#                        'Power': 40,
#                        'Type': 'Dark'},
#            'Scary Face': {'Accuracy': 100,
#                           'Description': 'The user frightens the target with a '
#                                          'scary face to harshly lower its '
#                                          'Speed stat.',
#                           'Effect %': '--',
#                           'Level': 19,
#                           'PP': 10,
#                           'Power': '--',
#                           'Type': 'Normal'},
#            'Screech': {'Accuracy': 85,
#                        'Description': 'An earsplitting screech harshly lowers '
#                                       "the target's Defense stat.",
#                        'Effect %': '--',
#                        'Level': 42,
#                        'PP': 40,
#                        'Power': '--',
#                        'Type': 'Normal'},
#            'Take Down': {'Accuracy': 85,
#                          'Description': 'A reckless, full-body charge attack '
#                                         'for slamming into the target. This '
#                                         'also damages the user a little.',
#                          'Effect %': '--',
#                          'Level': 15,
#                          'PP': 20,
#                          'Power': 90,
#                          'Type': 'Normal'},
#            'Zen Headbutt': {'Accuracy': 90,
#                             'Description': 'The user focuses its willpower to '
#                                            'its head and attacks the target. '
#                                            'This may also make the target '
#                                            'flinch.',
#                             'Effect %': 20,
#                             'Level': 37,
#                             'PP': 15,
#                             'Power': 80,
#                             'Type': 'Psychic'}},
#  'Name': 'Cranidos',
#  'Sp. Attack': 30,
#  'Sp. Defense': 30,
#  'Speed': 58,
#  'Total': 350,
#  'Type 1': 'Rock',
#  'Type 2': 'None',
#  'Weight (kg)': 31.5,
#  'Weight (lbs)': 69.4,
#  '_id': ObjectId('6759b84a0aaca17d8a11f6bf')}
# {'Abilities': ['Mold Breaker', 'Sheer Force'],
#  'Attack': 165,
#  'Capture Rate': 45,
#  'Category': 'Head Butt Pokémon',
#  'Defense': 60,
#  'Egg Steps': 7680,
#  'Exp Group': 'Erratic',
#  'HP': 97,
#  'Height (ft)': '5\'03"',
#  'Height (m)': 1.6,
#  'Id': '409',
#  'Moves': {'Ancient Power': {'Accuracy': 100,
#                              'Description': 'The user attacks with a '
#                                             'prehistoric power. This may also '
#                                             "raise all the user's stats at "
#                                             'once.',
#                              'Effect %': 10,
#                              'Level': 36,
#                              'PP': 5,
#                              'Power': 60,
#                              'Type': 'Rock'},
#            'Assurance': {'Accuracy': 100,
#                          'Description': 'If the target has already taken some '
#                                         'damage in the same turn, this '
#                                         "attack's power is doubled.",
#                          'Effect %': '--',
#                          'Level': 24,
#                          'PP': 10,
#                          'Power': 60,
#                          'Type': 'Dark'},
#            'Chip Away': {'Accuracy': 100,
#                          'Description': 'Looking for an opening, the user '
#                                         "strikes consistently. The target's "
#                                         "stat changes don't affect this "
#                                         "attack's damage.",
#                          'Effect %': '--',
#                          'Level': 28,
#                          'PP': 20,
#                          'Power': 70,
#                          'Type': 'Normal'},
#            'Endeavor': {'Accuracy': 100,
#                         'Description': 'This attack move cuts down the '
#                                        "target's HP to equal the user's HP.",
#                         'Effect %': '--',
#                         'Level': 'Evolve',
#                         'PP': 5,
#                         'Power': '??',
#                         'Type': 'Normal'},
#            'Focus Energy': {'Accuracy': '--',
#                             'Description': 'The user takes a deep breath and '
#                                            'focuses so that critical hits land '
#                                            'more easily.',
#                             'Effect %': '--',
#                             'Level': 6,
#                             'PP': 30,
#                             'Power': '--',
#                             'Type': 'Normal'},
#            'Head Smash': {'Accuracy': 80,
#                           'Description': 'The user attacks the target with a '
#                                          'hazardous, full-power headbutt. This '
#                                          'also damages the user terribly.',
#                           'Effect %': '--',
#                           'Level': 58,
#                           'PP': 5,
#                           'Power': 150,
#                           'Type': 'Rock'},
#            'Headbutt': {'Accuracy': 100,
#                         'Description': 'The user sticks out its head and '
#                                        'attacks by charging straight into the '
#                                        'target. This may also make the target '
#                                        'flinch.',
#                         'Effect %': 30,
#                         'Level': '—',
#                         'PP': 15,
#                         'Power': 70,
#                         'Type': 'Normal'},
#            'Leer': {'Accuracy': 100,
#                     'Description': 'The user gives opposing Pokémon an '
#                                    'intimidating leer that lowers the Defense '
#                                    'stat.',
#                     'Effect %': 100,
#                     'Level': '—',
#                     'PP': 30,
#                     'Power': '--',
#                     'Type': 'Normal'},
#            'Pursuit': {'Accuracy': 100,
#                        'Description': 'The power of this attack move is '
#                                       "doubled if it's used on a target that's "
#                                       'switching out of battle.',
#                        'Effect %': '--',
#                        'Level': 10,
#                        'PP': 20,
#                        'Power': 40,
#                        'Type': 'Dark'},
#            'Scary Face': {'Accuracy': 100,
#                           'Description': 'The user frightens the target with a '
#                                          'scary face to harshly lower its '
#                                          'Speed stat.',
#                           'Effect %': '--',
#                           'Level': 19,
#                           'PP': 10,
#                           'Power': '--',
#                           'Type': 'Normal'},
#            'Screech': {'Accuracy': 85,
#                        'Description': 'An earsplitting screech harshly lowers '
#                                       "the target's Defense stat.",
#                        'Effect %': '--',
#                        'Level': 51,
#                        'PP': 40,
#                        'Power': '--',
#                        'Type': 'Normal'},
#            'Take Down': {'Accuracy': 85,
#                          'Description': 'A reckless, full-body charge attack '
#                                         'for slamming into the target. This '
#                                         'also damages the user a little.',
#                          'Effect %': '--',
#                          'Level': 15,
#                          'PP': 20,
#                          'Power': 90,
#                          'Type': 'Normal'},
#            'Zen Headbutt': {'Accuracy': 90,
#                             'Description': 'The user focuses its willpower to '
#                                            'its head and attacks the target. '
#                                            'This may also make the target '
#                                            'flinch.',
#                             'Effect %': 20,
#                             'Level': 43,
#                             'PP': 15,
#                             'Power': 80,
#                             'Type': 'Psychic'}},
#  'Name': 'Rampardos',
#  'Sp. Attack': 65,
#  'Sp. Defense': 50,
#  'Speed': 58,
#  'Total': 495,
#  'Type 1': 'Rock',
#  'Type 2': 'None',
#  'Weight (kg)': 102.5,
#  'Weight (lbs)': 226.0,
#  '_id': ObjectId('6759b84a0aaca17d8a11f6c0')}
# {'Abilities': ['Sturdy', 'Soundproof'],
#  'Attack': 42,
#  'Capture Rate': 45,
#  'Category': 'Shield Pokémon',
#  'Defense': 118,
#  'Egg Steps': 7680,
#  'Exp Group': 'Erratic',
#  'HP': 30,
#  'Height (ft)': '1\'08"',
#  'Height (m)': 0.5,
#  'Id': '410',
#  'Moves': {'Ancient Power': {'Accuracy': 100,
#                              'Description': 'The user attacks with a '
#                                             'prehistoric power. This may also '
#                                             "raise all the user's stats at "
#                                             'once.',
#                              'Effect %': 10,
#                              'Level': 28,
#                              'PP': 5,
#                              'Power': 60,
#                              'Type': 'Rock'},
#            'Endure': {'Accuracy': '--',
#                       'Description': 'The user endures any attack with at '
#                                      'least 1 HP. Its chance of failing rises '
#                                      'if it is used in succession.',
#                       'Effect %': '--',
#                       'Level': 33,
#                       'PP': 10,
#                       'Power': '--',
#                       'Type': 'Normal'},
#            'Heavy Slam': {'Accuracy': 100,
#                           'Description': 'The user slams into the target with '
#                                          'its heavy body. The more the user '
#                                          'outweighs the target, the greater '
#                                          "the move's power.",
#                           'Effect %': '--',
#                           'Level': 42,
#                           'PP': 10,
#                           'Power': '??',
#                           'Type': 'Steel'},
#            'Iron Defense': {'Accuracy': '--',
#                             'Description': "The user hardens its body's "
#                                            'surface like iron, sharply raising '
#                                            'its Defense stat.',
#                             'Effect %': '--',
#                             'Level': 19,
#                             'PP': 15,
#                             'Power': '--',
#                             'Type': 'Steel'},
#            'Iron Head': {'Accuracy': 100,
#                          'Description': 'The user slams the target with its '
#                                         'steel-hard head. This may also make '
#                                         'the target flinch.',
#                          'Effect %': 30,
#                          'Level': 37,
#                          'PP': 15,
#                          'Power': 80,
#                          'Type': 'Steel'},
#            'Metal Burst': {'Accuracy': 100,
#                            'Description': 'The user retaliates with much '
#                                           'greater force against the opponent '
#                                           'that last inflicted damage on it.',
#                            'Effect %': '--',
#                            'Level': 1,
#                            'PP': 10,
#                            'Power': '??',
#                            'Type': 'Steel'},
#            'Metal Sound': {'Accuracy': 85,
#                            'Description': 'A horrible sound like scraping '
#                                           "metal harshly lowers the target's "
#                                           'Sp. Def stat.',
#                            'Effect %': '--',
#                            'Level': 10,
#                            'PP': 40,
#                            'Power': '--',
#                            'Type': 'Steel'},
#            'Protect': {'Accuracy': '--',
#                        'Description': 'Enables the user to evade all attacks. '
#                                       'Its chance of failing rises if it is '
#                                       'used in succession.',
#                        'Effect %': '--',
#                        'Level': '—',
#                        'PP': 10,
#                        'Power': '--',
#                        'Type': 'Normal'},
#            'Swagger': {'Accuracy': 85,
#                        'Description': 'The user enrages and confuses the '
#                                       'target. However, this also sharply '
#                                       "raises the target's Attack stat.",
#                        'Effect %': '--',
#                        'Level': 24,
#                        'PP': 15,
#                        'Power': '--',
#                        'Type': 'Normal'},
#            'Tackle': {'Accuracy': 100,
#                       'Description': 'A physical attack in which the user '
#                                      'charges and slams into the target with '
#                                      'its whole body.',
#                       'Effect %': '--',
#                       'Level': '—',
#                       'PP': 35,
#                       'Power': 40,
#                       'Type': 'Normal'},
#            'Take Down': {'Accuracy': 85,
#                          'Description': 'A reckless, full-body charge attack '
#                                         'for slamming into the target. This '
#                                         'also damages the user a little.',
#                          'Effect %': '--',
#                          'Level': 15,
#                          'PP': 20,
#                          'Power': 90,
#                          'Type': 'Normal'},
#            'Taunt': {'Accuracy': 100,
#                      'Description': 'The target is taunted into a rage that '
#                                     'allows it to use only attack moves for '
#                                     'three turns.',
#                      'Effect %': '--',
#                      'Level': 6,
#                      'PP': 20,
#                      'Power': '--',
#                      'Type': 'Dark'}},
#  'Name': 'Shieldon',
#  'Sp. Attack': 42,
#  'Sp. Defense': 88,
#  'Speed': 30,
#  'Total': 350,
#  'Type 1': 'Rock',
#  'Type 2': 'Steel',
#  'Weight (kg)': 57,
#  'Weight (lbs)': 125.7,
#  '_id': ObjectId('6759b84a0aaca17d8a11f6c1')}
# {'Abilities': ['Sturdy', 'Soundproof'],
#  'Attack': 52,
#  'Capture Rate': 45,
#  'Category': 'Shield Pokémon',
#  'Defense': 168,
#  'Egg Steps': 7680,
#  'Exp Group': 'Erratic',
#  'HP': 60,
#  'Height (ft)': '4\'03"',
#  'Height (m)': 1.3,
#  'Id': '411',
#  'Moves': {'Ancient Power': {'Accuracy': 100,
#                              'Description': 'The user attacks with a '
#                                             'prehistoric power. This may also '
#                                             "raise all the user's stats at "
#                                             'once.',
#                              'Effect %': 10,
#                              'Level': 28,
#                              'PP': 5,
#                              'Power': 60,
#                              'Type': 'Rock'},
#            'Block': {'Accuracy': '--',
#                      'Description': "The user blocks the target's way with "
#                                     'arms spread wide to prevent escape.',
#                      'Effect %': '--',
#                      'Level': 'Evolve',
#                      'PP': 5,
#                      'Power': '--',
#                      'Type': 'Normal'},
#            'Endure': {'Accuracy': '--',
#                       'Description': 'The user endures any attack with at '
#                                      'least 1 HP. Its chance of failing rises '
#                                      'if it is used in succession.',
#                       'Effect %': '--',
#                       'Level': 36,
#                       'PP': 10,
#                       'Power': '--',
#                       'Type': 'Normal'},
#            'Heavy Slam': {'Accuracy': 100,
#                           'Description': 'The user slams into the target with '
#                                          'its heavy body. The more the user '
#                                          'outweighs the target, the greater '
#                                          "the move's power.",
#                           'Effect %': '--',
#                           'Level': 51,
#                           'PP': 10,
#                           'Power': '??',
#                           'Type': 'Steel'},
#            'Iron Defense': {'Accuracy': '--',
#                             'Description': "The user hardens its body's "
#                                            'surface like iron, sharply raising '
#                                            'its Defense stat.',
#                             'Effect %': '--',
#                             'Level': 19,
#                             'PP': 15,
#                             'Power': '--',
#                             'Type': 'Steel'},
#            'Iron Head': {'Accuracy': 100,
#                          'Description': 'The user slams the target with its '
#                                         'steel-hard head. This may also make '
#                                         'the target flinch.',
#                          'Effect %': 30,
#                          'Level': 43,
#                          'PP': 15,
#                          'Power': 80,
#                          'Type': 'Steel'},
#            'Metal Burst': {'Accuracy': 100,
#                            'Description': 'The user retaliates with much '
#                                           'greater force against the opponent '
#                                           'that last inflicted damage on it.',
#                            'Effect %': '--',
#                            'Level': 1,
#                            'PP': 10,
#                            'Power': '??',
#                            'Type': 'Steel'},
#            'Metal Sound': {'Accuracy': 85,
#                            'Description': 'A horrible sound like scraping '
#                                           "metal harshly lowers the target's "
#                                           'Sp. Def stat.',
#                            'Effect %': '--',
#                            'Level': 10,
#                            'PP': 40,
#                            'Power': '--',
#                            'Type': 'Steel'},
#            'Protect': {'Accuracy': '--',
#                        'Description': 'Enables the user to evade all attacks. '
#                                       'Its chance of failing rises if it is '
#                                       'used in succession.',
#                        'Effect %': '--',
#                        'Level': '—',
#                        'PP': 10,
#                        'Power': '--',
#                        'Type': 'Normal'},
#            'Swagger': {'Accuracy': 85,
#                        'Description': 'The user enrages and confuses the '
#                                       'target. However, this also sharply '
#                                       "raises the target's Attack stat.",
#                        'Effect %': '--',
#                        'Level': 24,
#                        'PP': 15,
#                        'Power': '--',
#                        'Type': 'Normal'},
#            'Tackle': {'Accuracy': 100,
#                       'Description': 'A physical attack in which the user '
#                                      'charges and slams into the target with '
#                                      'its whole body.',
#                       'Effect %': '--',
#                       'Level': '—',
#                       'PP': 35,
#                       'Power': 40,
#                       'Type': 'Normal'},
#            'Take Down': {'Accuracy': 85,
#                          'Description': 'A reckless, full-body charge attack '
#                                         'for slamming into the target. This '
#                                         'also damages the user a little.',
#                          'Effect %': '--',
#                          'Level': 15,
#                          'PP': 20,
#                          'Power': 90,
#                          'Type': 'Normal'},
#            'Taunt': {'Accuracy': 100,
#                      'Description': 'The target is taunted into a rage that '
#                                     'allows it to use only attack moves for '
#                                     'three turns.',
#                      'Effect %': '--',
#                      'Level': 6,
#                      'PP': 20,
#                      'Power': '--',
#                      'Type': 'Dark'}},
#  'Name': 'Bastiodon',
#  'Sp. Attack': 47,
#  'Sp. Defense': 138,
#  'Speed': 30,
#  'Total': 495,
#  'Type 1': 'Rock',
#  'Type 2': 'Steel',
#  'Weight (kg)': 149.5,
#  'Weight (lbs)': 329.6,
#  '_id': ObjectId('6759b84a0aaca17d8a11f6c3')}
# {'Abilities': ['Vital Spirit', 'Pickup', 'Run Away'],
#  'Attack': 60,
#  'Capture Rate': 255,
#  'Category': 'Puppy Pokémon',
#  'Defense': 45,
#  'Egg Steps': 3840,
#  'Exp Group': 'Medium Slow',
#  'HP': 45,
#  'Height (ft)': '1\'04"',
#  'Height (m)': 0.4,
#  'Id': '506',
#  'Moves': {'Baby-Doll Eyes': {'Accuracy': 100,
#                               'Description': 'The user stares at the target '
#                                              'with its baby-doll eyes, which '
#                                              'lowers its Attack stat. This '
#                                              'move always goes first.',
#                               'Effect %': '--',
#                               'Level': 10,
#                               'PP': 30,
#                               'Power': '--',
#                               'Type': 'Fairy'},
#            'Bite': {'Accuracy': 100,
#                     'Description': 'The target is bitten with viciously sharp '
#                                    'fangs. This may also make the target '
#                                    'flinch.',
#                     'Effect %': 30,
#                     'Level': 8,
#                     'PP': 25,
#                     'Power': 60,
#                     'Type': 'Dark'},
#            'Crunch': {'Accuracy': 100,
#                       'Description': 'The user crunches up the target with '
#                                      'sharp fangs. This may also lower the '
#                                      "target's Defense stat.",
#                       'Effect %': 20,
#                       'Level': 22,
#                       'PP': 15,
#                       'Power': 80,
#                       'Type': 'Dark'},
#            'Giga Impact': {'Accuracy': 90,
# ...
# {'Abilities': ['Own Tempo', 'Ice Body', 'Sturdy'],
#  'Attack': 69,
#  'Capture Rate': 190,
#  'Category': 'Ice Chunk Pokémon',
#  'Defense': 85,
#  'Egg Steps': 5120,
#  'Exp Group': 'Medium Fast',
#  'HP': 55,
#  'Height (ft)': '3\'03"',
#  'Height (m)': 1,
#  'Id': '712',
#  'Moves': {'Avalanche': {'Accuracy': 100,
#                          'Description': 'The power of this attack move is '
#                                         'doubled if the user has been hurt by '
#                                         'the target in the same turn.',
#                          'Effect %': '--',
#                          'Level': 39,
#                          'PP': 10,
#                          'Power': 60,
#                          'Type': 'Ice'},
#            'Bite': {'Accuracy': 100,
#                     'Description': 'The target is bitten with viciously sharp '
#                                    'fangs. This may also make the target '
#                                    'flinch.',
#                     'Effect %': 30,
#                     'Level': '—',
#                     'PP': 25,
#                     'Power': 60,
#                     'Type': 'Dark'},
#            'Blizzard': {'Accuracy': 70,
#                         'Description': 'A howling blizzard is summoned to '
#                                        'strike opposing Pokémon. This may also '
#                                        'leave the opposing Pokémon frozen.',
#                         'Effect %': 10,
#                         'Level': 43,
#                         'PP': 5,
#                         'Power': 110,
#                         'Type': 'Ice'},
#            'Curse': {'Accuracy': '--',
#                      'Description': 'A move that works differently for the '
#                                     'Ghost type than for all other types.',
#                      'Effect %': '--',
#                      'Level': 22,
#                      'PP': 10,
#                      'Power': '--',
#                      'Type': 'Ghost'},
#            'Double-Edge': {'Accuracy': 100,
#                            'Description': 'A reckless, life-risking tackle. '
#                                           'This also damages the user quite a '
#                                           'lot.',
#                            'Effect %': '--',
#                            'Level': 49,
#                            'PP': 15,
#                            'Power': 120,
#                            'Type': 'Normal'},
#            'Harden': {'Accuracy': '--',
#                       'Description': 'The user stiffens all the muscles in its '
#                                      'body to raise its Defense stat.',
#                       'Effect %': '--',
#                       'Level': '—',
#                       'PP': 30,
#                       'Power': '--',
#                       'Type': 'Normal'},
#            'Ice Ball': {'Accuracy': 90,
#                         'Description': 'The user attacks the target for five '
#                                        "turns. The move's power increases each "
#                                        'time it hits.',
#                         'Effect %': '--',
#                         'Level': 30,
#                         'PP': 20,
#                         'Power': 30,
#                         'Type': 'Ice'},
#            'Ice Fang': {'Accuracy': 95,
#                         'Description': 'The user bites with cold-infused '
#                                        'fangs. This may also make the target '
#                                        'flinch or leave it frozen.',
#                         'Effect %': 20,
#                         'Level': 26,
#                         'PP': 15,
#                         'Power': 65,
#                         'Type': 'Ice'},
#            'Icy Wind': {'Accuracy': 95,
#                         'Description': 'The user attacks with a gust of '
#                                        'chilled air. This also lowers the '
#                                        "opposing Pokémon's Speed stats.",
#                         'Effect %': 100,
#                         'Level': 10,
#                         'PP': 15,
#                         'Power': 55,
#                         'Type': 'Ice'},
#            'Powder Snow': {'Accuracy': 100,
#                            'Description': 'The user attacks with a chilling '
#                                           'gust of powdery snow. This may also '
#                                           'freeze the opposing Pokémon.',
#                            'Effect %': 10,
#                            'Level': 5,
#                            'PP': 25,
#                            'Power': 40,
#                            'Type': 'Ice'},
#            'Rapid Spin': {'Accuracy': 100,
#                           'Description': 'A spin attack that can also '
#                                          'eliminate such moves as Bind, Wrap, '
#                                          'Leech Seed, and Spikes.',
#                           'Effect %': '--',
#                           'Level': 35,
#                           'PP': 40,
#                           'Power': 20,
#                           'Type': 'Normal'},
#            'Recover': {'Accuracy': '--',
#                        'Description': 'Restoring its own cells, the user '
#                                       'restores its own HP by half of its max '
#                                       'HP.',
#                        'Effect %': '--',
#                        'Level': 47,
#                        'PP': 10,
#                        'Power': '--',
#                        'Type': 'Normal'},
#            'Sharpen': {'Accuracy': '--',
#                        'Description': 'The user makes its edges more jagged,  '
#                                       'which raises its Attack stat.',
#                        'Effect %': '--',
#                        'Level': 20,
#                        'PP': 30,
#                        'Power': '--',
#                        'Type': 'Normal'},
#            'Tackle': {'Accuracy': 100,
#                       'Description': 'A physical attack in which the user '
#                                      'charges and slams into the target with '
#                                      'its whole body.',
#                       'Effect %': '--',
#                       'Level': '—',
#                       'PP': 35,
#                       'Power': 40,
#                       'Type': 'Normal'},
#            'Take Down': {'Accuracy': 85,
#                          'Description': 'A reckless, full-body charge attack '
#                                         'for slamming into the target. This '
#                                         'also damages the user a little.',
#                          'Effect %': '--',
#                          'Level': 15,
#                          'PP': 20,
#                          'Power': 90,
#                          'Type': 'Normal'}},
#  'Name': 'Bergmite',
#  'Sp. Attack': 32,
#  'Sp. Defense': 35,
#  'Speed': 28,
#  'Total': 304,
#  'Type 1': 'Ice',
#  'Type 2': 'None',
#  'Weight (kg)': 99.5,
#  'Weight (lbs)': 219.4,
#  '_id': ObjectId('6759b84a0aaca17d8a11f7ee')}
# {'Abilities': ['Own Tempo', 'Ice Body', 'Sturdy'],
#  'Attack': 117,
#  'Capture Rate': 55,
#  'Category': 'Iceberg Pokémon',
#  'Defense': 184,
#  'Egg Steps': 5120,
#  'Exp Group': 'Medium Fast',
#  'HP': 95,
#  'Height (ft)': '6\'07"',
#  'Height (m)': 2,
#  'Id': '713',
#  'Moves': {'Avalanche': {'Accuracy': 100,
#                          'Description': 'The power of this attack move is '
#                                         'doubled if the user has been hurt by '
#                                         'the target in the same turn.',
#                          'Effect %': '--',
#                          'Level': 42,
#                          'PP': 10,
#                          'Power': 60,
#                          'Type': 'Ice'},
#            'Bite': {'Accuracy': 100,
#                     'Description': 'The target is bitten with viciously sharp '
#                                    'fangs. This may also make the target '
#                                    'flinch.',
#                     'Effect %': 30,
#                     'Level': '—',
#                     'PP': 25,
#                     'Power': 60,
#                     'Type': 'Dark'},
#            'Blizzard': {'Accuracy': 70,
#                         'Description': 'A howling blizzard is summoned to '
#                                        'strike opposing Pokémon. This may also '
#                                        'leave the opposing Pokémon frozen.',
#                         'Effect %': 10,
#                         'Level': 46,
#                         'PP': 5,
#                         'Power': 110,
#                         'Type': 'Ice'},
#            'Body Slam': {'Accuracy': 100,
#                          'Description': 'The user drops onto the target with '
#                                         'its full body weight. This may also '
#                                         'leave the target with paralysis.',
#                          'Effect %': 30,
#                          'Level': 'Evolve',
#                          'PP': 15,
#                          'Power': 85,
#                          'Type': 'Normal'},
#            'Crunch': {'Accuracy': 100,
#                       'Description': 'The user crunches up the target with '
#                                      'sharp fangs. This may also lower the '
#                                      "target's Defense stat.",
#                       'Effect %': 20,
#                       'Level': 65,
#                       'PP': 15,
#                       'Power': 80,
#                       'Type': 'Dark'},
#            'Curse': {'Accuracy': '--',
#                      'Description': 'A move that works differently for the '
#                                     'Ghost type than for all other types.',
#                      'Effect %': '--',
#                      'Level': 22,
#                      'PP': 10,
#                      'Power': '--',
#                      'Type': 'Ghost'},
#            'Double-Edge': {'Accuracy': 100,
#                            'Description': 'A reckless, life-risking tackle. '
#                                           'This also damages the user quite a '
#                                           'lot.',
#                            'Effect %': '--',
#                            'Level': 56,
#                            'PP': 15,
#                            'Power': 120,
#                            'Type': 'Normal'},
#            'Harden': {'Accuracy': '--',
#                       'Description': 'The user stiffens all the muscles in its '
#                                      'body to raise its Defense stat.',
#                       'Effect %': '--',
#                       'Level': '—',
#                       'PP': 30,
#                       'Power': '--',
#                       'Type': 'Normal'},
#            'Ice Ball': {'Accuracy': 90,
#                         'Description': 'The user attacks the target for five '
#                                        "turns. The move's power increases each "
#                                        'time it hits.',
#                         'Effect %': '--',
#                         'Level': 30,
#                         'PP': 20,
#                         'Power': 30,
#                         'Type': 'Ice'},
#            'Ice Fang': {'Accuracy': 95,
#                         'Description': 'The user bites with cold-infused '
#                                        'fangs. This may also make the target '
#                                        'flinch or leave it frozen.',
#                         'Effect %': 20,
#                         'Level': 26,
#                         'PP': 15,
#                         'Power': 65,
#                         'Type': 'Ice'},
#            'Icy Wind': {'Accuracy': 95,
#                         'Description': 'The user attacks with a gust of '
#                                        'chilled air. This also lowers the '
#                                        "opposing Pokémon's Speed stats.",
#                         'Effect %': 100,
#                         'Level': 10,
#                         'PP': 15,
#                         'Power': 55,
#                         'Type': 'Ice'},
#            'Iron Defense': {'Accuracy': '--',
#                             'Description': "The user hardens its body's "
#                                            'surface like iron, sharply raising '
#                                            'its Defense stat.',
#                             'Effect %': '--',
#                             'Level': '—',
#                             'PP': 15,
#                             'Power': '--',
#                             'Type': 'Steel'},
#            'Powder Snow': {'Accuracy': 100,
#                            'Description': 'The user attacks with a chilling '
#                                           'gust of powdery snow. This may also '
#                                           'freeze the opposing Pokémon.',
#                            'Effect %': 10,
#                            'Level': 5,
#                            'PP': 25,
#                            'Power': 40,
#                            'Type': 'Ice'},
#            'Rapid Spin': {'Accuracy': 100,
#                           'Description': 'A spin attack that can also '
#                                          'eliminate such moves as Bind, Wrap, '
#                                          'Leech Seed, and Spikes.',
#                           'Effect %': '--',
#                           'Level': 35,
#                           'PP': 40,
#                           'Power': 20,
#                           'Type': 'Normal'},
#            'Recover': {'Accuracy': '--',
#                        'Description': 'Restoring its own cells, the user '
#                                       'restores its own HP by half of its max '
#                                       'HP.',
#                        'Effect %': '--',
#                        'Level': 51,
#                        'PP': 10,
#                        'Power': '--',
#                        'Type': 'Normal'},
#            'Sharpen': {'Accuracy': '--',
#                        'Description': 'The user makes its edges more jagged,  '
#                                       'which raises its Attack stat.',
#                        'Effect %': '--',
#                        'Level': 20,
#                        'PP': 30,
#                        'Power': '--',
#                        'Type': 'Normal'},
#            'Skull Bash': {'Accuracy': 100,
#                           'Description': 'The user tucks in its head to raise '
#                                          'its Defense stat on the first turn, '
#                                          'then rams the target on the next '
#                                          'turn.',
#                           'Effect %': 100,
#                           'Level': 60,
#                           'PP': 10,
#                           'Power': 130,
#                           'Type': 'Normal'},
#            'Tackle': {'Accuracy': 100,
#                       'Description': 'A physical attack in which the user '
#                                      'charges and slams into the target with '
#                                      'its whole body.',
#                       'Effect %': '--',
#                       'Level': '—',
#                       'PP': 35,
#                       'Power': 40,
#                       'Type': 'Normal'},
#            'Take Down': {'Accuracy': 85,
#                          'Description': 'A reckless, full-body charge attack '
#                                         'for slamming into the target. This '
#                                         'also damages the user a little.',
#                          'Effect %': '--',
#                          'Level': 15,
#                          'PP': 20,
#                          'Power': 90,
#                          'Type': 'Normal'}},
#  'Name': 'Avalugg',
#  'Sp. Attack': 44,
#  'Sp. Defense': 46,
#  'Speed': 28,
#  'Total': 514,
#  'Type 1': 'Ice',
#  'Type 2': 'None',
#  'Weight (kg)': 505,
#  'Weight (lbs)': 1113.3,
#  '_id': ObjectId('6759b84a0aaca17d8a11f7ef')}

# %% [markdown]
# #Pregunta 5
# Seleccione los pokemones que tienen el movimiento $\texttt{Take Down}$.
#
# **Hint**: Puede testear si es que una llave existe utilizando [$exists](https://docs.mongodb.com/manual/reference/operator/query/exists/)

# %%
for pokemon in collection.find({'Moves.Take Down': {'$exists': True}}):
    pprint.pprint(pokemon)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#                                      'confused.',
#                       'Effect %': '--',
#                       'Level': 90,
#                       'PP': 10,
#                       'Power': 120,
#                       'Type': 'Normal'}},
#  'Name': 'Larvesta',
#  'Sp. Attack': 50,
#  'Sp. Defense': 55,
#  'Speed': 60,
#  'Total': 360,
#  'Type 1': 'Bug',
#  'Type 2': 'Fire',
#  'Weight (kg)': 28.8,
#  'Weight (lbs)': 63.5,
#  '_id': ObjectId('6759b84a0aaca17d8a11f7a2')}
# {'Abilities': ['Justified'],
#  'Attack': 90,
#  'Capture Rate': 3,
#  'Category': 'Iron Will Pokémon',
#  'Defense': 129,
#  'Egg Steps': 20480,
#  'Exp Group': 'Slow',
#  'HP': 91,
#  'Height (ft)': '6\'11"',
#  'Height (m)': 2.1,
#  'Id': '638',
#  'Moves': {'Close Combat': {'Accuracy': 100,
#                             'Description': 'The user fights the target up '
#                                            'close without guarding itself. '
#                                            "This also lowers the user's "
#                                            'Defense and Sp. Def stats.',
#                             'Effect %': 100,
#                             'Level': 61,
#                             'PP': 5,
#                             'Power': 120,
#                             'Type': 'Fighting'},
#            'Double Kick': {'Accuracy': 100,
#                            'Description': 'The target is quickly kicked twice '
#                                           'in succession using both feet.',
#                            'Effect %': '--',
#                            'Level': '—',
#                            'PP': 30,
#                            'Power': 30,
#                            'Type': 'Fighting'},
#            'Helping Hand': {'Accuracy': '--',
#                             'Description': 'The user assists an ally by '
#                                            "boosting the power of that ally's "
#                                            'attack.',
#                             'Effect %': '--',
#                             'Level': 13,
#                             'PP': 20,
#                             'Power': '--',
#                             'Type': 'Normal'},
#            'Iron Head': {'Accuracy': 100,
#                          'Description': 'The user slams the target with its '
#                                         'steel-hard head. This may also make '
#                                         'the target flinch.',
#                          'Effect %': 30,
#                          'Level': 25,
#                          'PP': 15,
#                          'Power': 80,
#                          'Type': 'Steel'},
#            'Leer': {'Accuracy': 100,
#                     'Description': 'The user gives opposing Pokémon an '
#                                    'intimidating leer that lowers the Defense '
#                                    'stat.',
#                     'Effect %': 100,
#                     'Level': '—',
#                     'PP': 30,
#                     'Power': '--',
#                     'Type': 'Normal'},
#            'Metal Burst': {'Accuracy': 100,
#                            'Description': 'The user retaliates with much '
#                                           'greater force against the opponent '
#                                           'that last inflicted damage on it.',
#                            'Effect %': '--',
#                            'Level': 55,
#                            'PP': 10,
#                            'Power': '??',
#                            'Type': 'Steel'},
#            'Metal Claw': {'Accuracy': 95,
#                           'Description': 'The target is raked with steel '
#                                          'claws. This may also raise the '
#                                          "user's Attack stat.",
#                           'Effect %': 10,
#                           'Level': '—',
#                           'PP': 35,
#                           'Power': 50,
#                           'Type': 'Steel'},
#            'Quick Attack': {'Accuracy': 100,
#                             'Description': 'The user lunges at the target at a '
#                                            'speed that makes it almost '
#                                            'invisible. This move always goes '
#                                            'first.',
#                             'Effect %': '--',
#                             'Level': '—',
#                             'PP': 30,
#                             'Power': 40,
#                             'Type': 'Normal'},
#            'Quick Guard': {'Accuracy': '--',
#                            'Description': 'The user protects itself and its '
#                                           'allies from priority moves.',
#                            'Effect %': '--',
#                            'Level': 42,
#                            'PP': 15,
#                            'Power': '--',
#                            'Type': 'Fighting'},
#            'Retaliate': {'Accuracy': 100,
#                          'Description': 'The user gets revenge for a fainted '
#                                         'ally. If an ally fainted in the '
#                                         "previous turn, this move's power is "
#                                         'increased.',
#                          'Effect %': '--',
#                          'Level': 19,
#                          'PP': 5,
#                          'Power': 70,
#                          'Type': 'Normal'},
#            'Sacred Sword': {'Accuracy': 100,
#                             'Description': 'The user attacks by slicing with a '
#                                            "long horn. The target's stat "
#                                            "changes don't affect this attack's "
#                                            'damage.',
#                             'Effect %': '--',
#                             'Level': 31,
#                             'PP': 15,
#                             'Power': 90,
#                             'Type': 'Fighting'},
#            'Swords Dance': {'Accuracy': '--',
#                             'Description': 'A frenetic dance to uplift the '
#                                            'fighting spirit. This sharply '
#                                            "raises the user's Attack stat.",
#                             'Effect %': '--',
#                             'Level': 37,
#                             'PP': 20,
#                             'Power': '--',
#                             'Type': 'Normal'},
#            'Take Down': {'Accuracy': 85,
#                          'Description': 'A reckless, full-body charge attack '
#                                         'for slamming into the target. This '
#                                         'also damages the user a little.',
#                          'Effect %': '--',
#                          'Level': 7,
#                          'PP': 20,
#                          'Power': 90,
#                          'Type': 'Normal'},
#            'Work Up': {'Accuracy': '--',
#                        'Description': 'The user is roused, and its Attack and '
#                                       'Sp. Atk stats increase.',
#                        'Effect %': '--',
#                        'Level': 49,
#                        'PP': 30,
#                        'Power': '--',
#                        'Type': 'Normal'}},
#  'Name': 'Cobalion',
#  'Sp. Attack': 90,
#  'Sp. Defense': 72,
#  'Speed': 108,
#  'Total': 580,
#  'Type 1': 'Steel',
#  'Type 2': 'Fighting',
#  'Weight (kg)': 250,
#  'Weight (lbs)': 551.1,
#  '_id': ObjectId('6759b84a0aaca17d8a11f7a4')}
# {'Abilities': ['Justified'],
#  'Attack': 129,
#  'Capture Rate': 3,
#  'Category': 'Cavern Pokémon',
#  'Defense': 90,
#  'Egg Steps': 20480,
#  'Exp Group': 'Slow',
#  'HP': 91,
#  'Height (ft)': '6\'03"',
#  'Height (m)': 1.9,
#  'Id': '639',
#  'Moves': {'Close Combat': {'Accuracy': 100,
#                             'Description': 'The user fights the target up '
#                                            'close without guarding itself. '
#                                            "This also lowers the user's "
#                                            'Defense and Sp. Def stats.',
#                             'Effect %': 100,
#                             'Level': 61,
#                             'PP': 5,
#                             'Power': 120,
#                             'Type': 'Fighting'},
#            'Double Kick': {'Accuracy': 100,
#                            'Description': 'The target is quickly kicked twice '
#                                           'in succession using both feet.',
#                            'Effect %': '--',
#                            'Level': '—',
#                            'PP': 30,
#                            'Power': 30,
#                            'Type': 'Fighting'},
#            'Helping Hand': {'Accuracy': '--',
#                             'Description': 'The user assists an ally by '
#                                            "boosting the power of that ally's "
#                                            'attack.',
#                             'Effect %': '--',
#                             'Level': 13,
#                             'PP': 20,
#                             'Power': '--',
#                             'Type': 'Normal'},
#            'Leer': {'Accuracy': 100,
#                     'Description': 'The user gives opposing Pokémon an '
#                                    'intimidating leer that lowers the Defense '
#                                    'stat.',
#                     'Effect %': 100,
#                     'Level': '—',
#                     'PP': 30,
#                     'Power': '--',
#                     'Type': 'Normal'},
#            'Quick Attack': {'Accuracy': 100,
#                             'Description': 'The user lunges at the target at a '
#                                            'speed that makes it almost '
#                                            'invisible. This move always goes '
#                                            'first.',
#                             'Effect %': '--',
#                             'Level': '—',
#                             'PP': 30,
#                             'Power': 40,
#                             'Type': 'Normal'},
#            'Quick Guard': {'Accuracy': '--',
#                            'Description': 'The user protects itself and its '
#                                           'allies from priority moves.',
#                            'Effect %': '--',
#                            'Level': 42,
#                            'PP': 15,
#                            'Power': '--',
#                            'Type': 'Fighting'},
#            'Retaliate': {'Accuracy': 100,
#                          'Description': 'The user gets revenge for a fainted '
#                                         'ally. If an ally fainted in the '
#                                         "previous turn, this move's power is "
#                                         'increased.',
#                          'Effect %': '--',
#                          'Level': 19,
#                          'PP': 5,
#                          'Power': 70,
#                          'Type': 'Normal'},
#            'Rock Slide': {'Accuracy': 90,
#                           'Description': 'Large boulders are hurled at the '
#                                          'opposing Pokémon to inflict damage. '
#                                          'This may also make the opposing '
#                                          'Pokémon flinch.',
#                           'Effect %': 30,
#                           'Level': 25,
#                           'PP': 10,
#                           'Power': 75,
#                           'Type': 'Rock'},
#            'Sacred Sword': {'Accuracy': 100,
#                             'Description': 'The user attacks by slicing with a '
#                                            "long horn. The target's stat "
#                                            "changes don't affect this attack's "
#                                            'damage.',
#                             'Effect %': '--',
#                             'Level': 31,
#                             'PP': 15,
#                             'Power': 90,
#                             'Type': 'Fighting'},
#            'Smack Down': {'Accuracy': 100,
#                           'Description': 'The user throws a stone or similar '
#                                          'projectile to attack an opponent. A '
#                                          'flying Pokémon will fall to the '
#                                          "ground when it's hit.",
#                           'Effect %': 100,
#                           'Level': '—',
#                           'PP': 15,
#                           'Power': 50,
#                           'Type': 'Rock'},
#            'Stone Edge': {'Accuracy': 80,
#                           'Description': 'The user stabs the target from below '
#                                          'with sharpened stones. Critical hits '
#                                          'land more easily.',
#                           'Effect %': '--',
#                           'Level': 55,
#                           'PP': 5,
#                           'Power': 100,
#                           'Type': 'Rock'},
#            'Swords Dance': {'Accuracy': '--',
#                             'Description': 'A frenetic dance to uplift the '
#                                            'fighting spirit. This sharply '
#                                            "raises the user's Attack stat.",
#                             'Effect %': '--',
#                             'Level': 37,
#                             'PP': 20,
#                             'Power': '--',
#                             'Type': 'Normal'},
#            'Take Down': {'Accuracy': 85,
#                          'Description': 'A reckless, full-body charge attack '
#                                         'for slamming into the target. This '
#                                         'also damages the user a little.',
#                          'Effect %': '--',
#                          'Level': 7,
#                          'PP': 20,
#                          'Power': 90,
#                          'Type': 'Normal'},
#            'Work Up': {'Accuracy': '--',
#                        'Description': 'The user is roused, and its Attack and '
#                                       'Sp. Atk stats increase.',
#                        'Effect %': '--',
#                        'Level': 49,
#                        'PP': 30,
#                        'Power': '--',
#                        'Type': 'Normal'}},
#  'Name': 'Terrakion',
#  'Sp. Attack': 72,
#  'Sp. Defense': 90,
#  'Speed': 108,
#  'Total': 580,
#  'Type 1': 'Rock',
#  'Type 2': 'Fighting',
#  'Weight (kg)': 260,
#  'Weight (lbs)': 573.2,
#  '_id': ObjectId('6759b84a0aaca17d8a11f7a6')}
# {'Abilities': ['Justified'],
#  'Attack': 90,
#  'Capture Rate': 3,
#  'Category': 'Grassland Pokémon',
#  'Defense': 72,
#  'Egg Steps': 20480,
#  'Exp Group': 'Slow',
#  'HP': 91,
#  'Height (ft)': '6\'07"',
#  'Height (m)': 2,
#  'Id': '640',
#  'Moves': {'Close Combat': {'Accuracy': 100,
#                             'Description': 'The user fights the target up '
#                                            'close without guarding itself. '
#                                            "This also lowers the user's "
#                                            'Defense and Sp. Def stats.',
#                             'Effect %': 100,
#                             'Level': 61,
#                             'PP': 5,
#                             'Power': 120,
#                             'Type': 'Fighting'},
#            'Double Kick': {'Accuracy': 100,
#                            'Description': 'The target is quickly kicked twice '
#                                           'in succession using both feet.',
#                            'Effect %': '--',
#                            'Level': '—',
#                            'PP': 30,
#                            'Power': 30,
#                            'Type': 'Fighting'},
#            'Giga Drain': {'Accuracy': 100,
#                           'Description': 'A nutrient-draining attack. The '
#                                          "user's HP is restored by half the "
#                                          'damage taken by the target.',
#                           'Effect %': '--',
#                           'Level': 25,
#                           'PP': 10,
#                           'Power': 75,
#                           'Type': 'Grass'},
#            'Helping Hand': {'Accuracy': '--',
#                             'Description': 'The user assists an ally by '
#                                            "boosting the power of that ally's "
#                                            'attack.',
#                             'Effect %': '--',
#                             'Level': 13,
#                             'PP': 20,
#                             'Power': '--',
#                             'Type': 'Normal'},
#            'Leaf Blade': {'Accuracy': 100,
#                           'Description': 'The user handles a sharp leaf like a '
#                                          'sword and attacks by cutting its '
#                                          'target. Critical hits land more '
#                                          'easily.',
#                           'Effect %': '--',
#                           'Level': 55,
#                           'PP': 15,
#                           'Power': 90,
#                           'Type': 'Grass'},
#            'Leer': {'Accuracy': 100,
#                     'Description': 'The user gives opposing Pokémon an '
#                                    'intimidating leer that lowers the Defense '
#                                    'stat.',
#                     'Effect %': 100,
#                     'Level': '—',
#                     'PP': 30,
#                     'Power': '--',
#                     'Type': 'Normal'},
#            'Magical Leaf': {'Accuracy': '--',
#                             'Description': 'The user scatters curious leaves '
#                                            'that chase the target. This attack '
#                                            'never misses.',
#                             'Effect %': '--',
#                             'Level': '—',
#                             'PP': 20,
#                             'Power': 60,
#                             'Type': 'Grass'},
#            'Quick Attack': {'Accuracy': 100,
#                             'Description': 'The user lunges at the target at a '
#                                            'speed that makes it almost '
#                                            'invisible. This move always goes '
#                                            'first.',
#                             'Effect %': '--',
#                             'Level': '—',
#                             'PP': 30,
#                             'Power': 40,
#                             'Type': 'Normal'},
#            'Quick Guard': {'Accuracy': '--',
#                            'Description': 'The user protects itself and its '
#                                           'allies from priority moves.',
#                            'Effect %': '--',
#                            'Level': 42,
#                            'PP': 15,
#                            'Power': '--',
#                            'Type': 'Fighting'},
#            'Retaliate': {'Accuracy': 100,
#                          'Description': 'The user gets revenge for a fainted '
#                                         'ally. If an ally fainted in the '
#                                         "previous turn, this move's power is "
#                                         'increased.',
#                          'Effect %': '--',
#                          'Level': 19,
#                          'PP': 5,
#                          'Power': 70,
#                          'Type': 'Normal'},
#            'Sacred Sword': {'Accuracy': 100,
#                             'Description': 'The user attacks by slicing with a '
#                                            "long horn. The target's stat "
#                                            "changes don't affect this attack's "
#                                            'damage.',
#                             'Effect %': '--',
#                             'Level': 31,
#                             'PP': 15,
#                             'Power': 90,
#                             'Type': 'Fighting'},
#            'Swords Dance': {'Accuracy': '--',
#                             'Description': 'A frenetic dance to uplift the '
#                                            'fighting spirit. This sharply '
#                                            "raises the user's Attack stat.",
#                             'Effect %': '--',
#                             'Level': 37,
#                             'PP': 20,
#                             'Power': '--',
#                             'Type': 'Normal'},
#            'Take Down': {'Accuracy': 85,
#                          'Description': 'A reckless, full-body charge attack '
#                                         'for slamming into the target. This '
#                                         'also damages the user a little.',
#                          'Effect %': '--',
#                          'Level': 7,
#                          'PP': 20,
#                          'Power': 90,
#                          'Type': 'Normal'},
#            'Work Up': {'Accuracy': '--',
#                        'Description': 'The user is roused, and its Attack and '
#                                       'Sp. Atk stats increase.',
#                        'Effect %': '--',
#                        'Level': 49,
#                        'PP': 30,
#                        'Power': '--',
#                        'Type': 'Normal'}},
#  'Name': 'Virizion',
#  'Sp. Attack': 90,
#  'Sp. Defense': 129,
#  'Speed': 108,
#  'Total': 580,
#  'Type 1': 'Grass',
#  'Type 2': 'Fighting',
#  'Weight (kg)': 200,
#  'Weight (lbs)': 440.9,
#  '_id': ObjectId('6759b84a0aaca17d8a11f7a7')}
# {'Abilities': ['Justified'],
#  'Attack': 72,
#  'Capture Rate': 3,
#  'Category': 'Colt Pokémon',
#  'Defense': 90,
#  'Egg Steps': 20480,
#  'Exp Group': 'Slow',
#  'HP': 91,
#  'Height (ft)': '4\'07"',
#  'Height (m)': 1.4,
#  'Id': '647',
#  'Moves': {'Aqua Jet': {'Accuracy': 100,
#                         'Description': 'The user lunges at the target at a '
#                                        'speed that makes it almost invisible. '
#                                        'This move always goes first.',
#                         'Effect %': '--',
#                         'Level': '—',
#                         'PP': 20,
#                         'Power': 40,
#                         'Type': 'Water'},
#            'Aqua Tail': {'Accuracy': 90,
#                          'Description': 'The user attacks by swinging its tail '
#                                         'as if it were a vicious wave in a '
#                                         'raging storm.',
#                          'Effect %': '--',
#                          'Level': 37,
#                          'PP': 10,
#                          'Power': 90,
#                          'Type': 'Water'},
#            'Bubble Beam': {'Accuracy': 100,
#                            'Description': 'A spray of bubbles is forcefully '
#                                           'ejected at the target. This may '
#                                           'also lower its Speed stat.',
#                            'Effect %': 10,
#                            'Level': 13,
#                            'PP': 20,
#                            'Power': 65,
#                            'Type': 'Water'},
#            'Close Combat': {'Accuracy': 100,
#                             'Description': 'The user fights the target up '
#                                            'close without guarding itself. '
#                                            "This also lowers the user's "
#                                            'Defense and Sp. Def stats.',
#                             'Effect %': 100,
#                             'Level': 73,
#                             'PP': 5,
#                             'Power': 120,
#                             'Type': 'Fighting'},
#            'Double Kick': {'Accuracy': 100,
#                            'Description': 'The target is quickly kicked twice '
#                                           'in succession using both feet.',
#                            'Effect %': '--',
#                            'Level': 7,
#                            'PP': 30,
#                            'Power': 30,
#                            'Type': 'Fighting'},
#            'Helping Hand': {'Accuracy': '--',
#                             'Description': 'The user assists an ally by '
#                                            "boosting the power of that ally's "
#                                            'attack.',
#                             'Effect %': '--',
#                             'Level': 25,
#                             'PP': 20,
#                             'Power': '--',
#                             'Type': 'Normal'},
#            'Hydro Pump': {'Accuracy': 80,
#                           'Description': 'The target is blasted by a huge '
#                                          'volume of water launched under great '
#                                          'pressure.',
#                           'Effect %': '--',
#                           'Level': 67,
#                           'PP': 5,
#                           'Power': 110,
#                           'Type': 'Water'},
#            'Leer': {'Accuracy': 100,
#                     'Description': 'The user gives opposing Pokémon an '
#                                    'intimidating leer that lowers the Defense '
#                                    'stat.',
#                     'Effect %': 100,
#                     'Level': '—',
#                     'PP': 30,
#                     'Power': '--',
#                     'Type': 'Normal'},
#            'Quick Guard': {'Accuracy': '--',
#                            'Description': 'The user protects itself and its '
#                                           'allies from priority moves.',
#                            'Effect %': '--',
#                            'Level': 55,
#                            'PP': 15,
#                            'Power': '--',
#                            'Type': 'Fighting'},
#            'Retaliate': {'Accuracy': 100,
#                          'Description': 'The user gets revenge for a fainted '
#                                         'ally. If an ally fainted in the '
#                                         "previous turn, this move's power is "
#                                         'increased.',
#                          'Effect %': '--',
#                          'Level': 31,
#                          'PP': 5,
#                          'Power': 70,
#                          'Type': 'Normal'},
#            'Sacred Sword': {'Accuracy': 100,
#                             'Description': 'The user attacks by slicing with a '
#                                            "long horn. The target's stat "
#                                            "changes don't affect this attack's "
#                                            'damage.',
#                             'Effect %': '--',
#                             'Level': 43,
#                             'PP': 15,
#                             'Power': 90,
#                             'Type': 'Fighting'},
#            'Swords Dance': {'Accuracy': '--',
#                             'Description': 'A frenetic dance to uplift the '
#                                            'fighting spirit. This sharply '
#                                            "raises the user's Attack stat.",
#                             'Effect %': '--',
#                             'Level': 49,
#                             'PP': 20,
#                             'Power': '--',
#                             'Type': 'Normal'},
#            'Take Down': {'Accuracy': 85,
#                          'Description': 'A reckless, full-body charge attack '
#                                         'for slamming into the target. This '
#                                         'also damages the user a little.',
#                          'Effect %': '--',
#                          'Level': 19,
#                          'PP': 20,
#                          'Power': 90,
#                          'Type': 'Normal'},
#            'Work Up': {'Accuracy': '--',
#                        'Description': 'The user is roused, and its Attack and '
#                                       'Sp. Atk stats increase.',
#                        'Effect %': '--',
#                        'Level': 61,
#                        'PP': 30,
#                        'Power': '--',
#                        'Type': 'Normal'}},
#  'Name': 'Keldeo',
#  'Sp. Attack': 129,
#  'Sp. Defense': 90,
#  'Speed': 108,
#  'Total': 580,
#  'Type 1': 'Water',
#  'Type 2': 'Fighting',
#  'Weight (kg)': 48.5,
#  'Weight (lbs)': 106.9,
#  '_id': ObjectId('6759b84a0aaca17d8a11f7ae')}
# {'Abilities': ['Overgrow', 'Bulletproof'],
#  'Attack': 61,
#  'Capture Rate': 45,
#  'Category': 'Spiky Nut Pokémon',
#  'Defense': 65,
#  'Egg Steps': 5120,
#  'Exp Group': 'Medium Slow',
#  'HP': 56,
#  'Height (ft)': '1\'04"',
#  'Height (m)': 0.4,
#  'Id': '650',
#  'Moves': {'Bite': {'Accuracy': 100,
#                     'Description': 'The target is bitten with viciously sharp '
#                                    'fangs. This may also make the target '
#                                    'flinch.',
#                     'Effect %': 30,
#                     'Level': 11,
#                     'PP': 25,
#                     'Power': 60,
#                     'Type': 'Dark'},
#            'Body Slam': {'Accuracy': 100,
#                          'Description': 'The user drops onto the target with '
#                                         'its full body weight. This may also '
#                                         'leave the target with paralysis.',
#                          'Effect %': 30,
#                          'Level': 42,
#                          'PP': 15,
#                          'Power': 85,
#                          'Type': 'Normal'},
#            'Bulk Up': {'Accuracy': '--',
#                        'Description': 'The user tenses its muscles to bulk up '
#                                       'its body, raising both its Attack and '
#                                       'Defense stats.',
#                        'Effect %': '--',
#                        'Level': 39,
#                        'PP': 20,
#                        'Power': '--',
#                        'Type': 'Fighting'},
#            'Growl': {'Accuracy': 100,
#                      'Description': 'The user growls in an endearing way, '
#                                     'making opposing Pokémon less wary. This '
#                                     'lowers their Attack stat.',
#                      'Effect %': '--',
#                      'Level': '—',
#                      'PP': 40,
#                      'Power': '--',
#                      'Type': 'Normal'},
#            'Leech Seed': {'Accuracy': 90,
#                           'Description': 'A seed is planted on the target. It '
#                                          'steals some HP from the target every '
#                                          'turn.',
#                           'Effect %': '--',
#                           'Level': 15,
#                           'PP': 10,
#                           'Power': '--',
#                           'Type': 'Grass'},
#            'Mud Shot': {'Accuracy': 95,
#                         'Description': 'The user attacks by hurling a blob of '
#                                        'mud at the target. This also lowers '
#                                        "the target's Speed stat.",
#                         'Effect %': 100,
#                         'Level': 35,
#                         'PP': 15,
#                         'Power': 55,
#                         'Type': 'Ground'},
#            'Pain Split': {'Accuracy': '--',
#                           'Description': "The user adds its HP to the target's "
#                                          'HP, then equally shares the combined '
#                                          'HP with the target.',
#                           'Effect %': '--',
#                           'Level': 45,
#                           'PP': 20,
#                           'Power': '--',
#                           'Type': 'Normal'},
#            'Pin Missile': {'Accuracy': 95,
#                            'Description': 'Sharp spikes are shot at the target '
#                                           'in rapid succession. They hit two '
#                                           'to five times in a row.',
#                            'Effect %': '--',
#                            'Level': 18,
#                            'PP': 20,
#                            'Power': 25,
#                            'Type': 'Bug'},
#            'Rollout': {'Accuracy': 90,
#                        'Description': 'The user continually rolls into the '
#                                       'target over five turns. It becomes more '
#                                       'powerful each time it hits.',
#                        'Effect %': '--',
#                        'Level': 8,
#                        'PP': 20,
#                        'Power': 30,
#                        'Type': 'Rock'},
#            'Seed Bomb': {'Accuracy': 100,
#                          'Description': 'The user slams a barrage of '
#                                         'hard-shelled seeds down on the target '
#                                         'from above.',
#                          'Effect %': '--',
#                          'Level': 32,
#                          'PP': 15,
#                          'Power': 80,
#                          'Type': 'Grass'},
#            'Take Down': {'Accuracy': 85,
#                          'Description': 'A reckless, full-body charge attack '
#                                         'for slamming into the target. This '
#                                         'also damages the user a little.',
#                          'Effect %': '--',
#                          'Level': 27,
#                          'PP': 20,
#                          'Power': 90,
#                          'Type': 'Normal'},
#            'Vine Whip': {'Accuracy': 100,
#                          'Description': 'The target is struck with slender, '
#                                         'whiplike vines to inflict damage.',
#                          'Effect %': '--',
#                          'Level': 5,
#                          'PP': 25,
#                          'Power': 45,
#                          'Type': 'Grass'},
#            'Wood Hammer': {'Accuracy': 100,
#                            'Description': 'The user slams its rugged body into '
#                                           'the target to attack. This also '
#                                           'damages the user quite a lot.',
#                            'Effect %': '--',
#                            'Level': 48,
#                            'PP': 15,
#                            'Power': 120,
#                            'Type': 'Grass'}},
#  'Name': 'Chespin',
#  'Sp. Attack': 48,
#  'Sp. Defense': 45,
#  'Speed': 38,
#  'Total': 313,
#  'Type 1': 'Grass',
#  'Type 2': 'None',
#  'Weight (kg)': 9,
#  'Weight (lbs)': 19.8,
#  '_id': ObjectId('6759b84a0aaca17d8a11f7b0')}
# {'Abilities': ['Overgrow', 'Bulletproof'],
#  'Attack': 78,
#  'Capture Rate': 45,
#  'Category': 'Spiny Armor Pokémon',
#  'Defense': 95,
#  'Egg Steps': 5120,
#  'Exp Group': 'Medium Slow',
#  'HP': 61,
#  'Height (ft)': '2\'04"',
#  'Height (m)': 0.7,
#  'Id': '651',
#  'Moves': {'Bite': {'Accuracy': 100,
#                     'Description': 'The target is bitten with viciously sharp '
#                                    'fangs. This may also make the target '
#                                    'flinch.',
#                     'Effect %': 30,
#                     'Level': 11,
#                     'PP': 25,
#                     'Power': 60,
#                     'Type': 'Dark'},
#            'Body Slam': {'Accuracy': 100,
#                          'Description': 'The user drops onto the target with '
#                                         'its full body weight. This may also '
#                                         'leave the target with paralysis.',
#                          'Effect %': 30,
#                          'Level': 48,
#                          'PP': 15,
#                          'Power': 85,
#                          'Type': 'Normal'},
#            'Bulk Up': {'Accuracy': '--',
#                        'Description': 'The user tenses its muscles to bulk up '
#                                       'its body, raising both its Attack and '
#                                       'Defense stats.',
#                        'Effect %': '--',
#                        'Level': 44,
#                        'PP': 20,
#                        'Power': '--',
#                        'Type': 'Fighting'},
#            'Growl': {'Accuracy': 100,
#                      'Description': 'The user growls in an endearing way, '
#                                     'making opposing Pokémon less wary. This '
#                                     'lowers their Attack stat.',
#                      'Effect %': '--',
#                      'Level': '—',
#                      'PP': 40,
#                      'Power': '--',
#                      'Type': 'Normal'},
#            'Leech Seed': {'Accuracy': 90,
#                           'Description': 'A seed is planted on the target. It '
#                                          'steals some HP from the target every '
#                                          'turn.',
#                           'Effect %': '--',
#                           'Level': 15,
#                           'PP': 10,
#                           'Power': '--',
#                           'Type': 'Grass'},
#            'Mud Shot': {'Accuracy': 95,
#                         'Description': 'The user attacks by hurling a blob of '
#                                        'mud at the target. This also lowers '
#                                        "the target's Speed stat.",
#                         'Effect %': 100,
#                         'Level': 39,
#                         'PP': 15,
#                         'Power': 55,
#                         'Type': 'Ground'},
#            'Needle Arm': {'Accuracy': 100,
#                           'Description': 'The user attacks by wildly swinging '
#                                          'its thorny arms. This may also make '
#                                          'the target flinch.',
#                           'Effect %': 30,
#                           'Level': 'Evolve',
#                           'PP': 15,
#                           'Power': 60,
#                           'Type': 'Grass'},
#            'Pain Split': {'Accuracy': '--',
#                           'Description': "The user adds its HP to the target's "
#                                          'HP, then equally shares the combined '
#                                          'HP with the target.',
#                           'Effect %': '--',
#                           'Level': 52,
#                           'PP': 20,
#                           'Power': '--',
#                           'Type': 'Normal'},
#            'Pin Missile': {'Accuracy': 95,
#                            'Description': 'Sharp spikes are shot at the target '
#                                           'in rapid succession. They hit two '
#                                           'to five times in a row.',
#                            'Effect %': '--',
#                            'Level': 19,
#                            'PP': 20,
#                            'Power': 25,
#                            'Type': 'Bug'},
#            'Rollout': {'Accuracy': 90,
#                        'Description': 'The user continually rolls into the '
#                                       'target over five turns. It becomes more '
#                                       'powerful each time it hits.',
#                        'Effect %': '--',
#                        'Level': 8,
#                        'PP': 20,
#                        'Power': 30,
#                        'Type': 'Rock'},
#            'Seed Bomb': {'Accuracy': 100,
#                          'Description': 'The user slams a barrage of '
#                                         'hard-shelled seeds down on the target '
#                                         'from above.',
#                          'Effect %': '--',
#                          'Level': 35,
#                          'PP': 15,
#                          'Power': 80,
#                          'Type': 'Grass'},
#            'Take Down': {'Accuracy': 85,
#                          'Description': 'A reckless, full-body charge attack '
#                                         'for slamming into the target. This '
#                                         'also damages the user a little.',
#                          'Effect %': '--',
#                          'Level': 29,
#                          'PP': 20,
#                          'Power': 90,
#                          'Type': 'Normal'},
#            'Vine Whip': {'Accuracy': 100,
#                          'Description': 'The target is struck with slender, '
#                                         'whiplike vines to inflict damage.',
#                          'Effect %': '--',
#                          'Level': 5,
#                          'PP': 25,
#                          'Power': 45,
#                          'Type': 'Grass'},
#            'Wood Hammer': {'Accuracy': 100,
#                            'Description': 'The user slams its rugged body into '
#                                           'the target to attack. This also '
#                                           'damages the user quite a lot.',
#                            'Effect %': '--',
#                            'Level': 56,
#                            'PP': 15,
#                            'Power': 120,
#                            'Type': 'Grass'}},
#  'Name': 'Quilladin',
#  'Sp. Attack': 56,
#  'Sp. Defense': 58,
#  'Speed': 57,
#  'Total': 405,
#  'Type 1': 'Grass',
#  'Type 2': 'None',
#  'Weight (kg)': 29,
#  'Weight (lbs)': 63.9,
#  '_id': ObjectId('6759b84a0aaca17d8a11f7b2')}
# {'Abilities': ['Overgrow', 'Bulletproof'],
#  'Attack': 107,
#  'Capture Rate': 45,
#  'Category': 'Spiny Armor Pokémon',
#  'Defense': 122,
#  'Egg Steps': 5120,
#  'Exp Group': 'Medium Slow',
#  'HP': 88,
#  'Height (ft)': '5\'03"',
#  'Height (m)': 1.6,
#  'Id': '652',
#  'Moves': {'Belly Drum': {'Accuracy': '--',
#                           'Description': 'The user maximizes its Attack stat '
#                                          'in exchange for HP equal to half its '
#                                          'max HP.',
#                           'Effect %': '--',
#                           'Level': '—',
#                           'PP': 10,
#                           'Power': '--',
#                           'Type': 'Normal'},
#            'Bite': {'Accuracy': 100,
#                     'Description': 'The target is bitten with viciously sharp '
#                                    'fangs. This may also make the target '
#                                    'flinch.',
#                     'Effect %': 30,
#                     'Level': 11,
#                     'PP': 25,
#                     'Power': 60,
#                     'Type': 'Dark'},
#            'Body Slam': {'Accuracy': 100,
#                          'Description': 'The user drops onto the target with '
#                                         'its full body weight. This may also '
#                                         'leave the target with paralysis.',
#                          'Effect %': 30,
#                          'Level': 54,
#                          'PP': 15,
#                          'Power': 85,
#                          'Type': 'Normal'},
#            'Bulk Up': {'Accuracy': '--',
#                        'Description': 'The user tenses its muscles to bulk up '
#                                       'its body, raising both its Attack and '
#                                       'Defense stats.',
#                        'Effect %': '--',
#                        'Level': 48,
#                        'PP': 20,
#                        'Power': '--',
#                        'Type': 'Fighting'},
#            'Feint': {'Accuracy': 100,
#                      'Description': 'This attack hits a target using a move '
#                                     'such as Protect or Detect. This also '
#                                     'lifts the effects of those moves.',
#                      'Effect %': '--',
#                      'Level': '—',
#                      'PP': 10,
#                      'Power': 30,
#                      'Type': 'Normal'},
#            'Giga Impact': {'Accuracy': 90,
#                            'Description': 'The user charges at the target '
#                                           'using every bit of its power. The '
#                                           "user can't move on the next turn.",
#                            'Effect %': '--',
#                            'Level': 78,
#                            'PP': 5,
#                            'Power': 150,
#                            'Type': 'Normal'},
#            'Growl': {'Accuracy': 100,
#                      'Description': 'The user growls in an endearing way, '
#                                     'making opposing Pokémon less wary. This '
#                                     'lowers their Attack stat.',
#                      'Effect %': '--',
#                      'Level': '—',
#                      'PP': 40,
#                      'Power': '--',
#                      'Type': 'Normal'},
#            'Hammer Arm': {'Accuracy': 90,
#                           'Description': 'The user swings and hits with its '
#                                          'strong, heavy fist. It lowers the '
#                                          "user's Speed, however.",
#                           'Effect %': 100,
#                           'Level': 72,
#                           'PP': 10,
#                           'Power': 100,
#                           'Type': 'Fighting'},
#            'Leech Seed': {'Accuracy': 90,
#                           'Description': 'A seed is planted on the target. It '
#                                          'steals some HP from the target every '
#                                          'turn.',
#                           'Effect %': '--',
#                           'Level': 15,
#                           'PP': 10,
#                           'Power': '--',
#                           'Type': 'Grass'},
#            'Mud Shot': {'Accuracy': 95,
#                         'Description': 'The user attacks by hurling a blob of '
#                                        'mud at the target. This also lowers '
#                                        "the target's Speed stat.",
#                         'Effect %': 100,
#                         'Level': 41,
#                         'PP': 15,
#                         'Power': 55,
#                         'Type': 'Ground'},
#            'Needle Arm': {'Accuracy': 100,
#                           'Description': 'The user attacks by wildly swinging '
#                                          'its thorny arms. This may also make '
#                                          'the target flinch.',
#                           'Effect %': 30,
#                           'Level': '—',
#                           'PP': 15,
#                           'Power': 60,
#                           'Type': 'Grass'},
#            'Pain Split': {'Accuracy': '--',
#                           'Description': "The user adds its HP to the target's "
#                                          'HP, then equally shares the combined '
#                                          'HP with the target.',
#                           'Effect %': '--',
#                           'Level': 60,
#                           'PP': 20,
#                           'Power': '--',
#                           'Type': 'Normal'},
#            'Pin Missile': {'Accuracy': 95,
#                            'Description': 'Sharp spikes are shot at the target '
# ...
#                          'Effect %': '--',
#                          'Level': 40,
#                          'PP': 20,
#                          'Power': 90,
#                          'Type': 'Normal'},
#            'Thunder Fang': {'Accuracy': 95,
#                             'Description': 'The user bites with electrified '
#                                            'fangs. This may also make the '
#                                            'target flinch or leave it with '
#                                            'paralysis.',
#                             'Effect %': 20,
#                             'Level': '—',
#                             'PP': 15,
#                             'Power': 65,
#                             'Type': 'Electric'},
#            'Tri Attack': {'Accuracy': 100,
#                           'Description': 'The user strikes with a simultaneous '
#                                          'three-beam attack. May also burn, '
#                                          'freeze, or paralyze the target.',
#                           'Effect %': 20,
#                           'Level': 75,
#                           'PP': 10,
#                           'Power': 80,
#                           'Type': 'Normal'},
#            'X-Scissor': {'Accuracy': 100,
#                          'Description': 'The user slashes at the target by '
#                                         'crossing its scythes or claws as if '
#                                         'they were a pair of scissors.',
#                          'Effect %': '--',
#                          'Level': 35,
#                          'PP': 15,
#                          'Power': 80,
#                          'Type': 'Bug'}},
#  'Name': 'Silvally',
#  'Sp. Attack': 95,
#  'Sp. Defense': 95,
#  'Speed': 95,
#  'Total': 570,
#  'Type 1': 'Normal',
#  'Type 2': 'None',
#  'Weight (kg)': 100.5,
#  'Weight (lbs)': 221.6,
#  '_id': ObjectId('6759b84a0aaca17d8a11f82b')}
# {'Abilities': ['Shields Down'],
#  'Attack': 60,
#  'Capture Rate': 30,
#  'Category': 'Meteor Pokémon',
#  'Defense': 100,
#  'Egg Steps': 6400,
#  'Exp Group': 'Medium Slow',
#  'HP': 60,
#  'Height (ft)': '1\'00"',
#  'Height (m)': 0.3,
#  'Id': '774',
#  'Moves': {'Ancient Power': {'Accuracy': 100,
#                              'Description': 'The user attacks with a '
#                                             'prehistoric power. This may also '
#                                             "raise all the user's stats at "
#                                             'once.',
#                              'Effect %': 10,
#                              'Level': 17,
#                              'PP': 5,
#                              'Power': 60,
#                              'Type': 'Rock'},
#            'Autotomize': {'Accuracy': '--',
#                           'Description': 'The user sheds part of its body to '
#                                          'make itself lighter and sharply '
#                                          'raise its Speed stat.',
#                           'Effect %': '--',
#                           'Level': 31,
#                           'PP': 15,
#                           'Power': '--',
#                           'Type': 'Steel'},
#            'Confuse Ray': {'Accuracy': 100,
#                            'Description': 'The target is exposed to a sinister '
#                                           'ray that triggers confusion.',
#                            'Effect %': '--',
#                            'Level': 10,
#                            'PP': 10,
#                            'Power': '--',
#                            'Type': 'Ghost'},
#            'Cosmic Power': {'Accuracy': '--',
#                             'Description': 'The user absorbs a mystical power '
#                                            'from space to raise its Defense '
#                                            'and Sp. Def stats.',
#                             'Effect %': '--',
#                             'Level': 36,
#                             'PP': 20,
#                             'Power': '--',
#                             'Type': 'Psychic'},
#            'Defense Curl': {'Accuracy': '--',
#                             'Description': 'The user curls up to conceal weak '
#                                            'spots and raise its Defense stat.',
#                             'Effect %': '--',
#                             'Level': 3,
#                             'PP': 40,
#                             'Power': '--',
#                             'Type': 'Normal'},
#            'Double-Edge': {'Accuracy': 100,
#                            'Description': 'A reckless, life-risking tackle. '
#                                           'This also damages the user quite a '
#                                           'lot.',
#                            'Effect %': '--',
#                            'Level': 43,
#                            'PP': 15,
#                            'Power': 120,
#                            'Type': 'Normal'},
#            'Explosion': {'Accuracy': 100,
#                          'Description': 'The user attacks everything around it '
#                                         'by causing a tremendous explosion. '
#                                         'The user faints upon using this move.',
#                          'Effect %': '--',
#                          'Level': 50,
#                          'PP': 5,
#                          'Power': 250,
#                          'Type': 'Normal'},
#            'Power Gem': {'Accuracy': 100,
#                          'Description': 'The user attacks with a ray of light '
#                                         'that sparkles as if it were made of '
#                                         'gemstones.',
#                          'Effect %': '--',
#                          'Level': 38,
#                          'PP': 20,
#                          'Power': 80,
#                          'Type': 'Rock'},
#            'Rollout': {'Accuracy': 90,
#                        'Description': 'The user continually rolls into the '
#                                       'target over five turns. It becomes more '
#                                       'powerful each time it hits.',
#                        'Effect %': '--',
#                        'Level': 8,
#                        'PP': 20,
#                        'Power': 30,
#                        'Type': 'Rock'},
#            'Self-Destruct': {'Accuracy': 100,
#                              'Description': 'The user attacks everything '
#                                             'around it by causing an '
#                                             'explosion. The user faints upon '
#                                             'using this move.',
#                              'Effect %': '--',
#                              'Level': 22,
#                              'PP': 5,
#                              'Power': 200,
#                              'Type': 'Normal'},
#            'Shell Smash': {'Accuracy': '--',
#                            'Description': 'The user breaks its shell, which '
#                                           'lowers Defense and Sp. Def stats '
#                                           'but sharply raises its Attack, Sp. '
#                                           'Atk, and Speed stats.',
#                            'Effect %': '--',
#                            'Level': 45,
#                            'PP': 15,
#                            'Power': '--',
#                            'Type': 'Normal'},
#            'Stealth Rock': {'Accuracy': '--',
#                             'Description': 'The user lays a trap of levitating '
#                                            'stones around the opposing team. '
#                                            'The trap hurts opposing Pokémon '
#                                            'that switch into battle.',
#                             'Effect %': '--',
#                             'Level': 24,
#                             'PP': 20,
#                             'Power': '--',
#                             'Type': 'Rock'},
#            'Swift': {'Accuracy': '--',
#                      'Description': 'Star-shaped rays are shot at the opposing '
#                                     'Pokémon. This attack never misses.',
#                      'Effect %': '--',
#                      'Level': 15,
#                      'PP': 20,
#                      'Power': 60,
#                      'Type': 'Normal'},
#            'Tackle': {'Accuracy': 100,
#                       'Description': 'A physical attack in which the user '
#                                      'charges and slams into the target with '
#                                      'its whole body.',
#                       'Effect %': '--',
#                       'Level': '—',
#                       'PP': 35,
#                       'Power': 40,
#                       'Type': 'Normal'},
#            'Take Down': {'Accuracy': 85,
#                          'Description': 'A reckless, full-body charge attack '
#                                         'for slamming into the target. This '
#                                         'also damages the user a little.',
#                          'Effect %': '--',
#                          'Level': 29,
#                          'PP': 20,
#                          'Power': 90,
#                          'Type': 'Normal'}},
#  'Name': 'Minior',
#  'Sp. Attack': 60,
#  'Sp. Defense': 100,
#  'Speed': 60,
#  'Total': 440,
#  'Type 1': 'Rock',
#  'Type 2': 'Flying',
#  'Weight (kg)': 40,
#  'Weight (lbs)': 88.2,
#  '_id': ObjectId('6759b84a0aaca17d8a11f82d')}
# {'Abilities': ['Beast Boost'],
#  'Attack': 131,
#  'Capture Rate': 3,
#  'Category': 'Rampart Pokémon',
#  'Defense': 211,
#  'Egg Steps': 30720,
#  'Exp Group': 'Slow',
#  'HP': 61,
#  'Height (ft)': '18\'01"',
#  'Height (m)': 5.5,
#  'Id': '805',
#  'Moves': {'Autotomize': {'Accuracy': '--',
#                           'Description': 'The user sheds part of its body to '
#                                          'make itself lighter and sharply '
#                                          'raise its Speed stat.',
#                           'Effect %': '--',
#                           'Level': 31,
#                           'PP': 15,
#                           'Power': '--',
#                           'Type': 'Steel'},
#            'Bide': {'Accuracy': '--',
#                     'Description': 'The user endures attacks for two turns, '
#                                    'then strikes back to cause double the '
#                                    'damage taken.',
#                     'Effect %': '--',
#                     'Level': 17,
#                     'PP': 10,
#                     'Power': '??',
#                     'Type': 'Normal'},
#            'Double-Edge': {'Accuracy': 100,
#                            'Description': 'A reckless, life-risking tackle. '
#                                           'This also damages the user quite a '
#                                           'lot.',
#                            'Effect %': '--',
#                            'Level': 61,
#                            'PP': 15,
#                            'Power': 120,
#                            'Type': 'Normal'},
#            'Iron Defense': {'Accuracy': '--',
#                             'Description': "The user hardens its body's "
#                                            'surface like iron, sharply raising '
#                                            'its Defense stat.',
#                             'Effect %': '--',
#                             'Level': 37,
#                             'PP': 15,
#                             'Power': '--',
#                             'Type': 'Steel'},
#            'Iron Head': {'Accuracy': 100,
#                          'Description': 'The user slams the target with its '
#                                         'steel-hard head. This may also make '
#                                         'the target flinch.',
#                          'Effect %': 30,
#                          'Level': 43,
#                          'PP': 15,
#                          'Power': 80,
#                          'Type': 'Steel'},
#            'Protect': {'Accuracy': '--',
#                        'Description': 'Enables the user to evade all attacks. '
#                                       'Its chance of failing rises if it is '
#                                       'used in succession.',
#                        'Effect %': '--',
#                        'Level': '—',
#                        'PP': 10,
#                        'Power': '--',
#                        'Type': 'Normal'},
#            'Rock Blast': {'Accuracy': 90,
#                           'Description': 'The user hurls hard rocks at the '
#                                          'target. Two to five rocks are '
#                                          'launched in a row.',
#                           'Effect %': '--',
#                           'Level': 47,
#                           'PP': 10,
#                           'Power': 25,
#                           'Type': 'Rock'},
#            'Rock Slide': {'Accuracy': 90,
#                           'Description': 'Large boulders are hurled at the '
#                                          'opposing Pokémon to inflict damage. '
#                                          'This may also make the opposing '
#                                          'Pokémon flinch.',
#                           'Effect %': 30,
#                           'Level': 5,
#                           'PP': 10,
#                           'Power': 75,
#                           'Type': 'Rock'},
#            'Rock Throw': {'Accuracy': 90,
#                           'Description': 'The user picks up and throws a small '
#                                          'rock at the target to attack.',
#                           'Effect %': '--',
#                           'Level': 23,
#                           'PP': 15,
#                           'Power': 50,
#                           'Type': 'Rock'},
#            'Stealth Rock': {'Accuracy': '--',
#                             'Description': 'The user lays a trap of levitating '
#                                            'stones around the opposing team. '
#                                            'The trap hurts opposing Pokémon '
#                                            'that switch into battle.',
#                             'Effect %': '--',
#                             'Level': 11,
#                             'PP': 20,
#                             'Power': '--',
#                             'Type': 'Rock'},
#            'Tackle': {'Accuracy': 100,
#                       'Description': 'A physical attack in which the user '
#                                      'charges and slams into the target with '
#                                      'its whole body.',
#                       'Effect %': '--',
#                       'Level': '—',
#                       'PP': 35,
#                       'Power': 40,
#                       'Type': 'Normal'},
#            'Take Down': {'Accuracy': 85,
#                          'Description': 'A reckless, full-body charge attack '
#                                         'for slamming into the target. This '
#                                         'also damages the user a little.',
#                          'Effect %': '--',
#                          'Level': 19,
#                          'PP': 20,
#                          'Power': 90,
#                          'Type': 'Normal'},
#            'Wide Guard': {'Accuracy': '--',
#                           'Description': 'The user and its allies are '
#                                          'protected from wide-ranging attacks '
#                                          'for one turn.',
#                           'Effect %': '--',
#                           'Level': 53,
#                           'PP': 10,
#                           'Power': '--',
#                           'Type': 'Rock'}},
#  'Name': 'Stakataka',
#  'Sp. Attack': 53,
#  'Sp. Defense': 101,
#  'Speed': 13,
#  'Total': 570,
#  'Type 1': 'Rock',
#  'Type 2': 'Steel',
#  'Weight (kg)': 820,
#  'Weight (lbs)': 1807.8,
#  '_id': ObjectId('6759b84a0aaca17d8a11f84b')}

# %% [markdown]
# #Pregunta 6
# 1. Seleccione los pokemones que tienen la habilidad $\texttt{Telepathy}$

# %%
for pokemon in collection.find({'Abilities': 'Telepathy'}):
    print(pokemon['Name']+': '+str(pokemon['Abilities']))
# Out:
# Wobbuffet: ['Shadow Tag', 'Telepathy']
# Ralts: ['Synchronize', 'Trace', 'Telepathy']
# Kirlia: ['Synchronize', 'Trace', 'Telepathy']
# Gardevoir: ['Synchronize', 'Trace', 'Telepathy']
# Meditite: ['Pure Power', 'Telepathy']
# Medicham: ['Pure Power', 'Telepathy']
# Wynaut: ['Shadow Tag', 'Telepathy']
# Dialga: ['Pressure', 'Telepathy']
# Palkia: ['Pressure', 'Telepathy']
# Giratina: ['Pressure', 'Telepathy', 'Levitate']
# Munna: ['Forewarn', 'Synchronize', 'Telepathy']
# Musharna: ['Forewarn', 'Synchronize', 'Telepathy']
# Elgyem: ['Telepathy', 'Synchronize', 'Analytic']
# Beheeyem: ['Telepathy', 'Synchronize', 'Analytic']
# Noibat: ['Frisk', 'Infiltrator', 'Telepathy']
# Noivern: ['Frisk', 'Infiltrator', 'Telepathy']
# Oranguru: ['Inner Focus', 'Telepathy', 'Symbiosis']
# Tapu Lele: ['Psychic Surge', 'Telepathy']
# Tapu Bulu: ['Grassy Surge', 'Telepathy']
# Tapu Fini: ['Misty Surge', 'Telepathy']
# Tapu Koko: ['Electric Surge', 'Telepathy']

# %% [markdown]
# 2. Seleccione los pokemones que tienen la habilidad $\texttt{Telepathy}$
#  **y** $\texttt{Synchronize}$ (pueden tener mas habilidades aparte de estas dos.
#
#    **Hint**: puede utilizar el operador [$all](https://docs.mongodb.com/manual/tutorial/query-arrays/) .

# %%
for pokemon in collection.find({'Abilities': {'$all': ['Telepathy', 'Synchronize']}}):
    print(pokemon['Name'])
# Out:
# Ralts
# Kirlia
# Gardevoir
# Musharna
# Munna
# Elgyem
# Beheeyem

# %% [markdown]
# #Pregunta 7
# Para la siguiente pregunta vamos a crear un índice sobre la columna $\texttt{Category}$.

# %%
collection.create_index([('Category', 'text')])
# Out:
# 'Category_text'

# %% [markdown]
# Usando el operador [$text](https://docs.mongodb.com/manual/text-search/) responda a las siguientes consultas.
# 1.  Devuelva los nombres y categorías de los pokemons tales que su categoría contenga ya sea la palabra **Sea** o **Gas**.

# %%
for pokemon in collection.find({'$text': {'$search': 'Sea Gas'}}):
    print('el pokemon '+pokemon['Name']+' pertenece a la categoria :'+pokemon['Category'])
# Out:
# el pokemon Haunter pertenece a la categoria :Gas Pokémon
# el pokemon Gastly pertenece a la categoria :Gas Pokémon
# el pokemon Koffing pertenece a la categoria :Poison Gas Pokémon
# el pokemon Weezing pertenece a la categoria :Poison Gas Pokémon
# el pokemon Dhelmise pertenece a la categoria :Sea Creeper Pokémon
# el pokemon Pyukumuku pertenece a la categoria :Sea Cucumber Pokémon
# el pokemon Popplio pertenece a la categoria :Sea Lion Pokémon
# el pokemon Oshawott pertenece a la categoria :Sea Otter Pokémon
# el pokemon Phione pertenece a la categoria :Sea Drifter Pokémon
# el pokemon Gastrodon pertenece a la categoria :Sea Slug Pokémon
# el pokemon Shellos pertenece a la categoria :Sea Slug Pokémon
# el pokemon Floatzel pertenece a la categoria :Sea Weasel Pokémon
# el pokemon Buizel pertenece a la categoria :Sea Weasel Pokémon
# el pokemon Kyogre pertenece a la categoria :Sea Basin Pokémon
# el pokemon Gorebyss pertenece a la categoria :South Sea Pokémon
# el pokemon Huntail pertenece a la categoria :Deep Sea Pokémon
# el pokemon Lileep pertenece a la categoria :Sea Lily Pokémon
# el pokemon Dewgong pertenece a la categoria :Sea Lion Pokémon
# el pokemon Seel pertenece a la categoria :Sea Lion Pokémon

# %% [markdown]
# 2. Devuelva los nombres y categorías de los pokemons tales que su categoría contenga la palabra **Sea** y no **Deep**.

# %%
for pokemon in collection.find({'$text': {'$search': 'Sea -Deep'}}):
    print('el pokemon '+pokemon['Name']+' pertenece a la categoria :'+pokemon['Category'])
# Out:
# el pokemon Dhelmise pertenece a la categoria :Sea Creeper Pokémon
# el pokemon Pyukumuku pertenece a la categoria :Sea Cucumber Pokémon
# el pokemon Popplio pertenece a la categoria :Sea Lion Pokémon
# el pokemon Oshawott pertenece a la categoria :Sea Otter Pokémon
# el pokemon Phione pertenece a la categoria :Sea Drifter Pokémon
# el pokemon Gastrodon pertenece a la categoria :Sea Slug Pokémon
# el pokemon Shellos pertenece a la categoria :Sea Slug Pokémon
# el pokemon Floatzel pertenece a la categoria :Sea Weasel Pokémon
# el pokemon Buizel pertenece a la categoria :Sea Weasel Pokémon
# el pokemon Kyogre pertenece a la categoria :Sea Basin Pokémon
# el pokemon Gorebyss pertenece a la categoria :South Sea Pokémon
# el pokemon Lileep pertenece a la categoria :Sea Lily Pokémon
# el pokemon Dewgong pertenece a la categoria :Sea Lion Pokémon
# el pokemon Seel pertenece a la categoria :Sea Lion Pokémon

# %% [markdown]
# 3. Devuelva los nombres y categorías de los pokemons tales que su categoría contenga ambas palabras **Sea** y **Lion**.

# %%
for pokemon in collection.find({'$text': {'$search': ' \"Sea\" \"Lion\"'}}):
    print('el pokemon '+pokemon['Name']+' pertenece a la categoria :'+pokemon['Category'])
# Out:
# el pokemon Popplio pertenece a la categoria :Sea Lion Pokémon
# el pokemon Dewgong pertenece a la categoria :Sea Lion Pokémon
# el pokemon Seel pertenece a la categoria :Sea Lion Pokémon
